# %% [markdown]
# Timeseries Classification: KNN & DTW
# ===
# Mark Regan
#
# ---
# When it comes to building a classification algorithm, analysts have a broad range of open source options to choose from. However, for time series classification, there are less out-of-the box solutions. Many of the typical classification algorithms (Logistic Regression, Random Forests, SVM etc) are applicable to time-series data when the temporal data structure is abstracted away through feature engineering.
#
# My experience with this approach has been poor. The full timeseries feature vector contains a large amount of valuable information that can be lost through the process of flattening the datastructure.
#
# I began researching the domain of time series classification and was intrigued by a recommended technique called K Nearest Neighbors and Dynamic Time Warping. A meta analysis completed by Mitsa (2010) suggests that when it comes to timeseries classification, 1 Nearest Neighbor (K=1) and Dynamic Timewarping is very difficult to beat [1].
#
# ##K Nearest Neighbors & Dynamic Time Warping

# %%
from IPython.display import Image
Image('images/dtw_knn_schematic.png', width=780)

# %% [markdown]
# K Nearest Neighbors is a classification algorithm familiar to many. It takes a unlabled observation (the star above) and compares it to a population of labled observations (blue and orange circles). By finding the K nearest circles to the star, we can infer the class label for the star through majority voting.
#
# We can also use KNN in the context of time series data. The question becomes, "how do we compute the distance between two timeseries sequences"? "Dynamic Time Warping" is a technique that was heavily used for speech recognition in the 80s. The DTW algorithm finds the optimum alignment between two sequences of observations by warping the time dimension with certain constraints.
#
# Because of this temporal dimension warping, DTW is good for classifying sequences that have different frequences or that are out of phase. Later we'll see how we can use DTW to classify whether a person is walking, lying down, sitting etc.
#
# The above right diagram shows how a DTW distance matrix representation. Each cell is computed by measuring the distance between $A_i$ and $B_j$. The red path represents the shortest path and hence optimum alignment of the two sequences.
#
# $$DTW_{AB} = SUM(shortest\ paths_{AB})$$
#
# ####Max Warping Window Allowed
# Computing the full distance matrix between A and B scales with $O(n^2)$, where n is the number of sequences in A and B. This performance can be improved by constraining the amount of warping allowed. This limits the number of cells that need to be computed in the DTW distance matrix. Research by Keogh et al has shown that a warping window not only improves performance but also improves classification accuracy [2].

# %%
Image('images/max_window_warping.png')

# %% [markdown]
# ####Coded in Python
# The below python code represents the KNN & DTW classification algorithm. The following key methods are described:
#
# | Method        | Description                                                                                                           |
# |---------------|-----------------------------------------------------------------------------------------------------------------------|
# | `_dtw_distance` | computes the Dynamic Time Warping distance between two sequences                                                      |
# | `_dist_matrix`  | computes the distance matrix between $A$ and $B$                  |
# | `predict`       | uses both of the above methods to compute the class labels and probability of dataset $B$ through K Nearest Neighbors |

# %%
import sys
import collections
import itertools
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode
from scipy.spatial.distance import squareform

plt.style.use('bmh')
# %matplotlib inline

try:
    from IPython.display import clear_output
    have_ipython = True
except ImportError:
    have_ipython = False

class KnnDtw(object):
    """K-nearest neighbor classifier using dynamic time warping
    as the distance measure between pairs of time series arrays
    
    Arguments
    ---------
    n_neighbors : int, optional (default = 5)
        Number of neighbors to use by default for KNN
        
    max_warping_window : int, optional (default = infinity)
        Maximum warping window allowed by the DTW dynamic
        programming function
            
    subsample_step : int, optional (default = 1)
        Step size for the timeseries array. By setting subsample_step = 2,
        the timeseries length will be reduced by 50% because every second
        item is skipped. Implemented by x[:, ::subsample_step]
    """
    
    def __init__(self, n_neighbors=5, max_warping_window=10000, subsample_step=1):
        self.n_neighbors = n_neighbors
        self.max_warping_window = max_warping_window
        self.subsample_step = subsample_step
    
    def fit(self, x, l):
        """Fit the model using x as training data and l as class labels
        
        Arguments
        ---------
        x : array of shape [n_samples, n_timepoints]
            Training data set for input into KNN classifer
            
        l : array of shape [n_samples]
            Training labels for input into KNN classifier
        """
        
        self.x = x
        self.l = l
        
    def _dtw_distance(self, ts_a, ts_b, d = lambda x,y: abs(x-y)):
        """Returns the DTW similarity distance between two 2-D
        timeseries numpy arrays.

        Arguments
        ---------
        ts_a, ts_b : array of shape [n_samples, n_timepoints]
            Two arrays containing n_samples of timeseries data
            whose DTW distance between each sample of A and B
            will be compared
        
        d : DistanceMetric object (default = abs(x-y))
            the distance measure used for A_i - B_j in the
            DTW dynamic programming function
        
        Returns
        -------
        DTW distance between A and B
        """

        # Create cost matrix via broadcasting with large int
        ts_a, ts_b = np.array(ts_a), np.array(ts_b)
        M, N = len(ts_a), len(ts_b)
        cost = sys.maxsize * np.ones((M, N))

        # Initialize the first row and column
        cost[0, 0] = d(ts_a[0], ts_b[0])
        for i in np.arange(1, M):
            cost[i, 0] = cost[i-1, 0] + d(ts_a[i], ts_b[0])

        for j in np.arange(1, N):
            cost[0, j] = cost[0, j-1] + d(ts_a[0], ts_b[j])

        # Populate rest of cost matrix within window
        for i in np.arange(1, M):
            for j in np.arange(max(1, i - self.max_warping_window),
                            min(N, i + self.max_warping_window)):
                choices = cost[i - 1, j - 1], cost[i, j-1], cost[i-1, j]
                cost[i, j] = min(choices) + d(ts_a[i], ts_b[j])

        # Return DTW distance given window 
        return cost[-1, -1]
    
    def _dist_matrix(self, x, y):
        """Computes the M x N distance matrix between the training
        dataset and testing dataset (y) using the DTW distance measure
        
        Arguments
        ---------
        x : array of shape [n_samples, n_timepoints]
        
        y : array of shape [n_samples, n_timepoints]
        
        Returns
        -------
        Distance matrix between each item of x and y with
            shape [training_n_samples, testing_n_samples]
        """
        
        # Compute the distance matrix        
        dm_count = 0
        
        # Compute condensed distance matrix (upper triangle) of pairwise dtw distances
        # when x and y are the same array
        if(np.array_equal(x, y)):
            x_s = np.shape(x)
            dm = np.zeros((x_s[0] * (x_s[0] - 1)) // 2, dtype=np.double)
            
            p = ProgressBar(shape(dm)[0])
            
            for i in np.arange(0, x_s[0] - 1):
                for j in np.arange(i + 1, x_s[0]):
                    dm[dm_count] = self._dtw_distance(x[i, ::self.subsample_step],
                                                      y[j, ::self.subsample_step])
                    
                    dm_count += 1
                    p.animate(dm_count)
            
            # Convert to squareform
            dm = squareform(dm)
            return dm
        
        # Compute full distance matrix of dtw distnces between x and y
        else:
            x_s = np.shape(x)
            y_s = np.shape(y)
            dm = np.zeros((x_s[0], y_s[0])) 
            dm_size = x_s[0]*y_s[0]
            
            p = ProgressBar(dm_size)
        
            for i in np.arange(0, x_s[0]):
                for j in np.arange(0, y_s[0]):
                    dm[i, j] = self._dtw_distance(x[i, ::self.subsample_step],
                                                  y[j, ::self.subsample_step])
                    # Update progress bar
                    dm_count += 1
                    p.animate(dm_count)
        
            return dm
        
    def predict(self, x):
        """Predict the class labels or probability estimates for 
        the provided data

        Arguments
        ---------
          x : array of shape [n_samples, n_timepoints]
              Array containing the testing data set to be classified
          
        Returns
        -------
          2 arrays representing:
              (1) the predicted class labels 
              (2) the knn label count probability
        """
        
        dm = self._dist_matrix(x, self.x)

        # Identify the k nearest neighbors
        knn_idx = dm.argsort()[:, :self.n_neighbors]

        # Identify k nearest labels
        knn_labels = self.l[knn_idx]
        
        # Model Label
        mode_data = mode(knn_labels, axis=1)
        mode_label = mode_data[0]
        mode_proba = mode_data[1]/self.n_neighbors

        return mode_label.ravel(), mode_proba.ravel()

class ProgressBar:
    """This progress bar was taken from PYMC
    """
    def __init__(self, iterations):
        self.iterations = iterations
        self.prog_bar = '[]'
        self.fill_char = '*'
        self.width = 40
        self.__update_amount(0)
        if have_ipython:
            self.animate = self.animate_ipython
        else:
            self.animate = self.animate_noipython

    def animate_ipython(self, iter):
        print ('\r', self)
        sys.stdout.flush()
        self.update_iteration(iter + 1)

    def update_iteration(self, elapsed_iter):
        self.__update_amount((elapsed_iter / float(self.iterations)) * 100.0)
        self.prog_bar += '  %d of %s complete' % (elapsed_iter, self.iterations)

    def __update_amount(self, new_amount):
        percent_done = int(round((new_amount / 100.0) * 100.0))
        all_full = self.width - 2
        num_hashes = int(round((percent_done / 100.0) * all_full))
        self.prog_bar = '[' + self.fill_char * num_hashes + ' ' * (all_full - num_hashes) + ']'
        pct_place = (len(self.prog_bar) // 2) - len(str(percent_done))
        pct_string = '%d%%' % percent_done
        self.prog_bar = self.prog_bar[0:pct_place] + \
            (pct_string + self.prog_bar[pct_place + len(pct_string):])

    def __str__(self):
        return str(self.prog_bar)

# %% [markdown]
# #### Measuring the DTW distance
# The DTW distance between two sequences can be calculated using the `_dtw_distance()` method

# %%
time = np.linspace(0,20,1000)
amplitude_a = 5*np.sin(time)
amplitude_b = 3*np.sin(time + 1)

m = KnnDtw()
distance = m._dtw_distance(amplitude_a, amplitude_b)

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('DTW distance between A and B is %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Time')
_ = plt.legend()

# %% [markdown]
# It is also possible to compute the distance between each pair of two collections of inputs by using the `_dist_matrix()` method. These are the two methods which underpin the KnnDtw() classification algorithm. In the next section we will use the `fit()` and `predict()` method to train our classifier and predict class labels forunseen data.

# %%
m._dist_matrix(np.random.random((4,50)), np.random.random((4,50)))
# Out:
#  [                  0%                  ]
#  [*****            12%                  ]  2 of 16 complete
#  [*******          19%                  ]  3 of 16 complete
#  [**********       25%                  ]  4 of 16 complete
#  [************     31%                  ]  5 of 16 complete
#  [**************   38%                  ]  6 of 16 complete
#  [*****************44%                  ]  7 of 16 complete
#  [*****************50%                  ]  8 of 16 complete
#  [*****************56%*                 ]  9 of 16 complete
#  [*****************62%****              ]  10 of 16 complete
#  [*****************69%******            ]  11 of 16 complete
#  [*****************75%********          ]  12 of 16 complete
#  [*****************81%***********       ]  13 of 16 complete
#  [*****************88%*************     ]  14 of 16 complete
#  [*****************94%****************  ]  15 of 16 complete
#  [****************100%******************]  16 of 16 complete
# array([[10.47255671,  7.89237245,  9.66794085,  9.16370091],
#        [ 8.9882324 ,  9.63859799,  9.70224751,  9.32971482],
#        [10.53162957,  9.04131262,  9.6895473 ,  9.44023894],
#        [ 7.5953065 ,  8.34424099,  8.3782756 ,  8.79351647]])

# %% [markdown]
# ## Human Activity Recognition Dataset
# The Human Activity Recognition Dataset (HAR) dataset is chosen to test the classification performance of DTW & KNN [3].

# %%
Image('images/stand-sit-run.jpg')

# %% [markdown]
# > The experiments were carried out with a group of 30 volunteers within an age bracket of 19-48 years. Each person performed six activities (walking, walking upstairs, walking downstairs, sitting, standing and laying) wearing a smartphone (Samsung Galaxy S II) on the waist. Using its embedded accelerometer and gyroscope, we captured 3-axial linear acceleration and 3-axial angular velocity at a constant rate of 50Hz. The experiments have been video-recorded to label the data manually.
#
# The remainder of this analysis uses a training and test dataset provided by the authors. They have combined the above timeseries signals and created a single timeseries feature vector. Unfortunately, their methodology is not described.
#
# ####Import the HAR dataset

# %%
# Import the HAR dataset
x_train_file = open('data/UCI-HAR-Dataset/train/X_train.txt', 'r')
y_train_file = open('data/UCI-HAR-Dataset/train/y_train.txt', 'r')

x_test_file = open('data/UCI-HAR-Dataset/test/X_test.txt', 'r')
y_test_file = open('data/UCI-HAR-Dataset/test/y_test.txt', 'r')

# Create empty lists
x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

# Loop through datasets
for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
# Convert to numpy for efficiency
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# #### Visualizing sample observations from the HAR dataset

# %%
plt.figure(figsize=(11,7))
colors = ['#D62728','#2C9F2C','#FD7F23','#1F77B4','#9467BD',
          '#8C564A','#7F7F7F','#1FBECF','#E377C2','#BCBD27']

for i, r in enumerate([0,27,65,100,145,172]):
    plt.subplot(3,2,i+1)
    plt.plot(x_train[r][:100], label=labels[y_train[r]], color=colors[i], linewidth=2)
    plt.xlabel('Samples @50Hz')
    plt.legend(loc='upper left')
    plt.tight_layout()

# %% [markdown]
# #### Model Performance
# The performance of the KNN & DTW classifier is measured by comparing the class labels from the holdout dataset against predictions made by the classifier. The HAR dataset was pre-split into 70% training and 30% test. Cross validation was not performed.

# %%
m = KnnDtw(n_neighbors=1, max_warping_window=10)
m.fit(x_train[::10], y_train[::10])
label, proba = m.predict(x_test[::10])
# Out:
#  [                  0%                  ]
#  [                  0%                  ]  2 of 217120 complete
#  [                  0%                  ]  3 of 217120 complete
#  [                  0%                  ]  4 of 217120 complete
#  [                  0%                  ]  5 of 217120 complete
#  [                  0%                  ]  6 of 217120 complete
#  [                  0%                  ]  7 of 217120 complete
#  [                  0%                  ]  8 of 217120 complete
#  [                  0%                  ]  9 of 217120 complete
#  [                  0%                  ]  10 of 217120 complete
#  [                  0%                  ]  11 of 217120 complete
#  [                  0%                  ]  12 of 217120 complete
#  [                  0%                  ]  13 of 217120 complete
#  [                  0%                  ]  14 of 217120 complete
#  [                  0%                  ]  15 of 217120 complete
#  [                  0%                  ]  16 of 217120 complete
#  [                  0%                  ]  17 of 217120 complete
#  [                  0%                  ]  18 of 217120 complete
#  [                  0%                  ]  19 of 217120 complete
#  [                  0%                  ]  20 of 217120 complete
#  [                  0%                  ]  21 of 217120 complete
#  [                  0%                  ]  22 of 217120 complete
#  [                  0%                  ]  23 of 217120 complete
#  [                  0%                  ]  24 of 217120 complete
#  [                  0%                  ]  25 of 217120 complete
#  [                  0%                  ]  26 of 217120 complete
#  [                  0%                  ]  27 of 217120 complete
#  [                  0%                  ]  28 of 217120 complete
#  [                  0%                  ]  29 of 217120 complete
#  [                  0%                  ]  30 of 217120 complete
#  [                  0%                  ]  31 of 217120 complete
#  [                  0%                  ]  32 of 217120 complete
#  [                  0%                  ]  33 of 217120 complete
#  [                  0%                  ]  34 of 217120 complete
#  [                  0%                  ]  35 of 217120 complete
#  [                  0%                  ]  36 of 217120 complete
#  [                  0%                  ]  37 of 217120 complete
#  [                  0%                  ]  38 of 217120 complete
#  [                  0%                  ]  39 of 217120 complete
#  [                  0%                  ]  40 of 217120 complete
#  [                  0%                  ]  41 of 217120 complete
#  [                  0%                  ]  42 of 217120 complete
#  [                  0%                  ]  43 of 217120 complete
#  [                  0%                  ]  44 of 217120 complete
#  [                  0%                  ]  45 of 217120 complete
#  [                  0%                  ]  46 of 217120 complete
#  [                  0%                  ]  47 of 217120 complete
#  [                  0%                  ]  48 of 217120 complete
#  [                  0%                  ]  49 of 217120 complete
#  [                  0%                  ]  50 of 217120 complete
#  [                  0%                  ]  51 of 217120 complete
#  [                  0%                  ]  52 of 217120 complete
#  [                  0%                  ]  53 of 217120 complete
#  [                  0%                  ]  54 of 217120 complete
#  [                  0%                  ]  55 of 217120 complete
#  [                  0%                  ]  56 of 217120 complete
#  [                  0%                  ]  57 of 217120 complete
#  [                  0%                  ]  58 of 217120 complete
#  [                  0%                  ]  59 of 217120 complete
#  [                  0%                  ]  60 of 217120 complete
#  [                  0%                  ]  61 of 217120 complete
#  [                  0%                  ]  62 of 217120 complete
#  [                  0%                  ]  63 of 217120 complete
#  [                  0%                  ]  64 of 217120 complete
#  [                  0%                  ]  65 of 217120 complete
#  [                  0%                  ]  66 of 217120 complete
#  [                  0%                  ]  67 of 217120 complete
#  [                  0%                  ]  68 of 217120 complete
#  [                  0%                  ]  69 of 217120 complete
#  [                  0%                  ]  70 of 217120 complete
#  [                  0%                  ]  71 of 217120 complete
#  [                  0%                  ]  72 of 217120 complete
#  [                  0%                  ]  73 of 217120 complete
#  [                  0%                  ]  74 of 217120 complete
#  [                  0%                  ]  75 of 217120 complete
#  [                  0%                  ]  76 of 217120 complete
#  [                  0%                  ]  77 of 217120 complete
#  [                  0%                  ]  78 of 217120 complete
#  [                  0%                  ]  79 of 217120 complete
#  [                  0%                  ]  80 of 217120 complete
#  [                  0%                  ]  81 of 217120 complete
#  [                  0%                  ]  82 of 217120 complete
#  [                  0%                  ]  83 of 217120 complete
#  [                  0%                  ]  84 of 217120 complete
#  [                  0%                  ]  85 of 217120 complete
#  [                  0%                  ]  86 of 217120 complete
#  [                  0%                  ]  87 of 217120 complete
#  [                  0%                  ]  88 of 217120 complete
#  [                  0%                  ]  89 of 217120 complete
#  [                  0%                  ]  90 of 217120 complete
#  [                  0%                  ]  91 of 217120 complete
#  [                  0%                  ]  92 of 217120 complete
#  [                  0%                  ]  93 of 217120 complete
#  [                  0%                  ]  94 of 217120 complete
#  [                  0%                  ]  95 of 217120 complete
#  [                  0%                  ]  96 of 217120 complete
#  [                  0%                  ]  97 of 217120 complete
#  [                  0%                  ]  98 of 217120 complete
#  [                  0%                  ]  99 of 217120 complete
#  [                  0%                  ]  100 of 217120 complete
#  [                  0%                  ]  101 of 217120 complete
#  [                  0%                  ]  102 of 217120 complete
#  [                  0%                  ]  103 of 217120 complete
#  [                  0%                  ]  104 of 217120 complete
#  [                  0%                  ]  105 of 217120 complete
#  [                  0%                  ]  106 of 217120 complete
#  [                  0%                  ]  107 of 217120 complete
#  [                  0%                  ]  108 of 217120 complete
#  [                  0%                  ]  109 of 217120 complete
#  [                  0%                  ]  110 of 217120 complete
#  [                  0%                  ]  111 of 217120 complete
#  [                  0%                  ]  112 of 217120 complete
#  [                  0%                  ]  113 of 217120 complete
#  [                  0%                  ]  114 of 217120 complete
#  [                  0%                  ]  115 of 217120 complete
#  [                  0%                  ]  116 of 217120 complete
#  [                  0%                  ]  117 of 217120 complete
#  [                  0%                  ]  118 of 217120 complete
#  [                  0%                  ]  119 of 217120 complete
#  [                  0%                  ]  120 of 217120 complete
#  [                  0%                  ]  121 of 217120 complete
#  [                  0%                  ]  122 of 217120 complete
#  [                  0%                  ]  123 of 217120 complete
#  [                  0%                  ]  124 of 217120 complete
#  [                  0%                  ]  125 of 217120 complete
#  [                  0%                  ]  126 of 217120 complete
#  [                  0%                  ]  127 of 217120 complete
#  [                  0%                  ]  128 of 217120 complete
#  [                  0%                  ]  129 of 217120 complete
#  [                  0%                  ]  130 of 217120 complete
#  [                  0%                  ]  131 of 217120 complete
#  [                  0%                  ]  132 of 217120 complete
#  [                  0%                  ]  133 of 217120 complete
#  [                  0%                  ]  134 of 217120 complete
#  [                  0%                  ]  135 of 217120 complete
#  [                  0%                  ]  136 of 217120 complete
#  [                  0%                  ]  137 of 217120 complete
#  [                  0%                  ]  138 of 217120 complete
#  [                  0%                  ]  139 of 217120 complete
#  [                  0%                  ]  140 of 217120 complete
#  [                  0%                  ]  141 of 217120 complete
#  [                  0%                  ]  142 of 217120 complete
#  [                  0%                  ]  143 of 217120 complete
#  [                  0%                  ]  144 of 217120 complete
#  [                  0%                  ]  145 of 217120 complete
#  [                  0%                  ]  146 of 217120 complete
#  [                  0%                  ]  147 of 217120 complete
#  [                  0%                  ]  148 of 217120 complete
#  [                  0%                  ]  149 of 217120 complete
#  [                  0%                  ]  150 of 217120 complete
#  [                  0%                  ]  151 of 217120 complete
#  [                  0%                  ]  152 of 217120 complete
#  [                  0%                  ]  153 of 217120 complete
#  [                  0%                  ]  154 of 217120 complete
#  [                  0%                  ]  155 of 217120 complete
#  [                  0%                  ]  156 of 217120 complete
#  [                  0%                  ]  157 of 217120 complete
#  [                  0%                  ]  158 of 217120 complete
#  [                  0%                  ]  159 of 217120 complete
#  [                  0%                  ]  160 of 217120 complete
#  [                  0%                  ]  161 of 217120 complete
#  [                  0%                  ]  162 of 217120 complete
#  [                  0%                  ]  163 of 217120 complete
#  [                  0%                  ]  164 of 217120 complete
#  [                  0%                  ]  165 of 217120 complete
#  [                  0%                  ]  166 of 217120 complete
#  [                  0%                  ]  167 of 217120 complete
#  [                  0%                  ]  168 of 217120 complete
#  [                  0%                  ]  169 of 217120 complete
#  [                  0%                  ]  170 of 217120 complete
#  [                  0%                  ]  171 of 217120 complete
#  [                  0%                  ]  172 of 217120 complete
#  [                  0%                  ]  173 of 217120 complete
#  [                  0%                  ]  174 of 217120 complete
#  [                  0%                  ]  175 of 217120 complete
#  [                  0%                  ]  176 of 217120 complete
#  [                  0%                  ]  177 of 217120 complete
#  [                  0%                  ]  178 of 217120 complete
#  [                  0%                  ]  179 of 217120 complete
#  [                  0%                  ]  180 of 217120 complete
#  [                  0%                  ]  181 of 217120 complete
#  [                  0%                  ]  182 of 217120 complete
#  [                  0%                  ]  183 of 217120 complete
#  [                  0%                  ]  184 of 217120 complete
#  [                  0%                  ]  185 of 217120 complete
#  [                  0%                  ]  186 of 217120 complete
#  [                  0%                  ]  187 of 217120 complete
#  [                  0%                  ]  188 of 217120 complete
#  [                  0%                  ]  189 of 217120 complete
#  [                  0%                  ]  190 of 217120 complete
#  [                  0%                  ]  191 of 217120 complete
#  [                  0%                  ]  192 of 217120 complete
#  [                  0%                  ]  193 of 217120 complete
#  [                  0%                  ]  194 of 217120 complete
#  [                  0%                  ]  195 of 217120 complete
#  [                  0%                  ]  196 of 217120 complete
#  [                  0%                  ]  197 of 217120 complete
#  [                  0%                  ]  198 of 217120 complete
#  [                  0%                  ]  199 of 217120 complete
#  [                  0%                  ]  200 of 217120 complete
#  [                  0%                  ]  201 of 217120 complete
#  [                  0%                  ]  202 of 217120 complete
#  [                  0%                  ]  203 of 217120 complete
#  [                  0%                  ]  204 of 217120 complete
#  [                  0%                  ]  205 of 217120 complete
#  [                  0%                  ]  206 of 217120 complete
#  [                  0%                  ]  207 of 217120 complete
#  [                  0%                  ]  208 of 217120 complete
#  [                  0%                  ]  209 of 217120 complete
#  [                  0%                  ]  210 of 217120 complete
#  [                  0%                  ]  211 of 217120 complete
#  [                  0%                  ]  212 of 217120 complete
#  [                  0%                  ]  213 of 217120 complete
#  [                  0%                  ]  214 of 217120 complete
#  [                  0%                  ]  215 of 217120 complete
#  [                  0%                  ]  216 of 217120 complete
#  [                  0%                  ]  217 of 217120 complete
#  [                  0%                  ]  218 of 217120 complete
#  [                  0%                  ]  219 of 217120 complete
#  [                  0%                  ]  220 of 217120 complete
#  [                  0%                  ]  221 of 217120 complete
#  [                  0%                  ]  222 of 217120 complete
#  [                  0%                  ]  223 of 217120 complete
#  [                  0%                  ]  224 of 217120 complete
#  [                  0%                  ]  225 of 217120 complete
#  [                  0%                  ]  226 of 217120 complete
#  [                  0%                  ]  227 of 217120 complete
#  [                  0%                  ]  228 of 217120 complete
#  [                  0%                  ]  229 of 217120 complete
#  [                  0%                  ]  230 of 217120 complete
#  [                  0%                  ]  231 of 217120 complete
#  [                  0%                  ]  232 of 217120 complete
#  [                  0%                  ]  233 of 217120 complete
#  [                  0%                  ]  234 of 217120 complete
#  [                  0%                  ]  235 of 217120 complete
#  [                  0%                  ]  236 of 217120 complete
#  [                  0%                  ]  237 of 217120 complete
#  [                  0%                  ]  238 of 217120 complete
#  [                  0%                  ]  239 of 217120 complete
#  [                  0%                  ]  240 of 217120 complete
#  [                  0%                  ]  241 of 217120 complete
#  [                  0%                  ]  242 of 217120 complete
#  [                  0%                  ]  243 of 217120 complete
#  [                  0%                  ]  244 of 217120 complete
#  [                  0%                  ]  245 of 217120 complete
#  [                  0%                  ]  246 of 217120 complete
#  [                  0%                  ]  247 of 217120 complete
#  [                  0%                  ]  248 of 217120 complete
#  [                  0%                  ]  249 of 217120 complete
#  [                  0%                  ]  250 of 217120 complete
#  [                  0%                  ]  251 of 217120 complete
#  [                  0%                  ]  252 of 217120 complete
#  [                  0%                  ]  253 of 217120 complete
#  [                  0%                  ]  254 of 217120 complete
#  [                  0%                  ]  255 of 217120 complete
#  [                  0%                  ]  256 of 217120 complete
#  [                  0%                  ]  257 of 217120 complete
#  [                  0%                  ]  258 of 217120 complete
#  [                  0%                  ]  259 of 217120 complete
#  [                  0%                  ]  260 of 217120 complete
#  [                  0%                  ]  261 of 217120 complete
#  [                  0%                  ]  262 of 217120 complete
#  [                  0%                  ]  263 of 217120 complete
#  [                  0%                  ]  264 of 217120 complete
#  [                  0%                  ]  265 of 217120 complete
#  [                  0%                  ]  266 of 217120 complete
#  [                  0%                  ]  267 of 217120 complete
#  [                  0%                  ]  268 of 217120 complete
#  [                  0%                  ]  269 of 217120 complete
#  [                  0%                  ]  270 of 217120 complete
#  [                  0%                  ]  271 of 217120 complete
#  [                  0%                  ]  272 of 217120 complete
#  [                  0%                  ]  273 of 217120 complete
#  [                  0%                  ]  274 of 217120 complete
#  [                  0%                  ]  275 of 217120 complete
#  [                  0%                  ]  276 of 217120 complete
#  [                  0%                  ]  277 of 217120 complete
#  [                  0%                  ]  278 of 217120 complete
#  [                  0%                  ]  279 of 217120 complete
#  [                  0%                  ]  280 of 217120 complete
#  [                  0%                  ]  281 of 217120 complete
#  [                  0%                  ]  282 of 217120 complete
#  [                  0%                  ]  283 of 217120 complete
#  [                  0%                  ]  284 of 217120 complete
#  [                  0%                  ]  285 of 217120 complete
#  [                  0%                  ]  286 of 217120 complete
#  [                  0%                  ]  287 of 217120 complete
#  [                  0%                  ]  288 of 217120 complete
#  [                  0%                  ]  289 of 217120 complete
#  [                  0%                  ]  290 of 217120 complete
#  [                  0%                  ]  291 of 217120 complete
#  [                  0%                  ]  292 of 217120 complete
#  [                  0%                  ]  293 of 217120 complete
#  [                  0%                  ]  294 of 217120 complete
#  [                  0%                  ]  295 of 217120 complete
#  [                  0%                  ]  296 of 217120 complete
#  [                  0%                  ]  297 of 217120 complete
#  [                  0%                  ]  298 of 217120 complete
#  [                  0%                  ]  299 of 217120 complete
#  [                  0%                  ]  300 of 217120 complete
#  [                  0%                  ]  301 of 217120 complete
#  [                  0%                  ]  302 of 217120 complete
#  [                  0%                  ]  303 of 217120 complete
#  [                  0%                  ]  304 of 217120 complete
#  [                  0%                  ]  305 of 217120 complete
#  [                  0%                  ]  306 of 217120 complete
#  [                  0%                  ]  307 of 217120 complete
#  [                  0%                  ]  308 of 217120 complete
#  [                  0%                  ]  309 of 217120 complete
#  [                  0%                  ]  310 of 217120 complete
#  [                  0%                  ]  311 of 217120 complete
#  [                  0%                  ]  312 of 217120 complete
#  [                  0%                  ]  313 of 217120 complete
#  [                  0%                  ]  314 of 217120 complete
#  [                  0%                  ]  315 of 217120 complete
#  [                  0%                  ]  316 of 217120 complete
#  [                  0%                  ]  317 of 217120 complete
#  [                  0%                  ]  318 of 217120 complete
#  [                  0%                  ]  319 of 217120 complete
#  [                  0%                  ]  320 of 217120 complete
#  [                  0%                  ]  321 of 217120 complete
#  [                  0%                  ]  322 of 217120 complete
#  [                  0%                  ]  323 of 217120 complete
#  [                  0%                  ]  324 of 217120 complete
#  [                  0%                  ]  325 of 217120 complete
#  [                  0%                  ]  326 of 217120 complete
#  [                  0%                  ]  327 of 217120 complete
#  [                  0%                  ]  328 of 217120 complete
#  [                  0%                  ]  329 of 217120 complete
#  [                  0%                  ]  330 of 217120 complete
#  [                  0%                  ]  331 of 217120 complete
#  [                  0%                  ]  332 of 217120 complete
#  [                  0%                  ]  333 of 217120 complete
#  [                  0%                  ]  334 of 217120 complete
#  [                  0%                  ]  335 of 217120 complete
#  [                  0%                  ]  336 of 217120 complete
#  [                  0%                  ]  337 of 217120 complete
#  [                  0%                  ]  338 of 217120 complete
#  [                  0%                  ]  339 of 217120 complete
#  [                  0%                  ]  340 of 217120 complete
#  [                  0%                  ]  341 of 217120 complete
#  [                  0%                  ]  342 of 217120 complete
#  [                  0%                  ]  343 of 217120 complete
#  [                  0%                  ]  344 of 217120 complete
#  [                  0%                  ]  345 of 217120 complete
#  [                  0%                  ]  346 of 217120 complete
#  [                  0%                  ]  347 of 217120 complete
#  [                  0%                  ]  348 of 217120 complete
#  [                  0%                  ]  349 of 217120 complete
#  [                  0%                  ]  350 of 217120 complete
#  [                  0%                  ]  351 of 217120 complete
#  [                  0%                  ]  352 of 217120 complete
#  [                  0%                  ]  353 of 217120 complete
#  [                  0%                  ]  354 of 217120 complete
#  [                  0%                  ]  355 of 217120 complete
#  [                  0%                  ]  356 of 217120 complete
#  [                  0%                  ]  357 of 217120 complete
#  [                  0%                  ]  358 of 217120 complete
#  [                  0%                  ]  359 of 217120 complete
#  [                  0%                  ]  360 of 217120 complete
#  [                  0%                  ]  361 of 217120 complete
#  [                  0%                  ]  362 of 217120 complete
#  [                  0%                  ]  363 of 217120 complete
#  [                  0%                  ]  364 of 217120 complete
#  [                  0%                  ]  365 of 217120 complete
#  [                  0%                  ]  366 of 217120 complete
#  [                  0%                  ]  367 of 217120 complete
#  [                  0%                  ]  368 of 217120 complete
#  [                  0%                  ]  369 of 217120 complete
#  [                  0%                  ]  370 of 217120 complete
#  [                  0%                  ]  371 of 217120 complete
#  [                  0%                  ]  372 of 217120 complete
#  [                  0%                  ]  373 of 217120 complete
#  [                  0%                  ]  374 of 217120 complete
#  [                  0%                  ]  375 of 217120 complete
#  [                  0%                  ]  376 of 217120 complete
#  [                  0%                  ]  377 of 217120 complete
#  [                  0%                  ]  378 of 217120 complete
#  [                  0%                  ]  379 of 217120 complete
#  [                  0%                  ]  380 of 217120 complete
#  [                  0%                  ]  381 of 217120 complete
#  [                  0%                  ]  382 of 217120 complete
#  [                  0%                  ]  383 of 217120 complete
#  [                  0%                  ]  384 of 217120 complete
#  [                  0%                  ]  385 of 217120 complete
#  [                  0%                  ]  386 of 217120 complete
#  [                  0%                  ]  387 of 217120 complete
#  [                  0%                  ]  388 of 217120 complete
#  [                  0%                  ]  389 of 217120 complete
#  [                  0%                  ]  390 of 217120 complete
#  [                  0%                  ]  391 of 217120 complete
#  [                  0%                  ]  392 of 217120 complete
#  [                  0%                  ]  393 of 217120 complete
#  [                  0%                  ]  394 of 217120 complete
#  [                  0%                  ]  395 of 217120 complete
#  [                  0%                  ]  396 of 217120 complete
#  [                  0%                  ]  397 of 217120 complete
#  [                  0%                  ]  398 of 217120 complete
#  [                  0%                  ]  399 of 217120 complete
#  [                  0%                  ]  400 of 217120 complete
#  [                  0%                  ]  401 of 217120 complete
#  [                  0%                  ]  402 of 217120 complete
#  [                  0%                  ]  403 of 217120 complete
#  [                  0%                  ]  404 of 217120 complete
#  [                  0%                  ]  405 of 217120 complete
#  [                  0%                  ]  406 of 217120 complete
#  [                  0%                  ]  407 of 217120 complete
#  [                  0%                  ]  408 of 217120 complete
#  [                  0%                  ]  409 of 217120 complete
#  [                  0%                  ]  410 of 217120 complete
#  [                  0%                  ]  411 of 217120 complete
#  [                  0%                  ]  412 of 217120 complete
#  [                  0%                  ]  413 of 217120 complete
#  [                  0%                  ]  414 of 217120 complete
#  [                  0%                  ]  415 of 217120 complete
#  [                  0%                  ]  416 of 217120 complete
#  [                  0%                  ]  417 of 217120 complete
#  [                  0%                  ]  418 of 217120 complete
#  [                  0%                  ]  419 of 217120 complete
#  [                  0%                  ]  420 of 217120 complete
#  [                  0%                  ]  421 of 217120 complete
#  [                  0%                  ]  422 of 217120 complete
#  [                  0%                  ]  423 of 217120 complete
#  [                  0%                  ]  424 of 217120 complete
#  [                  0%                  ]  425 of 217120 complete
#  [                  0%                  ]  426 of 217120 complete
#  [                  0%                  ]  427 of 217120 complete
#  [                  0%                  ]  428 of 217120 complete
#  [                  0%                  ]  429 of 217120 complete
#  [                  0%                  ]  430 of 217120 complete
#  [                  0%                  ]  431 of 217120 complete
#  [                  0%                  ]  432 of 217120 complete
#  [                  0%                  ]  433 of 217120 complete
#  [                  0%                  ]  434 of 217120 complete
#  [                  0%                  ]  435 of 217120 complete
#  [                  0%                  ]  436 of 217120 complete
#  [                  0%                  ]  437 of 217120 complete
#  [                  0%                  ]  438 of 217120 complete
#  [                  0%                  ]  439 of 217120 complete
#  [                  0%                  ]  440 of 217120 complete
#  [                  0%                  ]  441 of 217120 complete
#  [                  0%                  ]  442 of 217120 complete
#  [                  0%                  ]  443 of 217120 complete
#  [                  0%                  ]  444 of 217120 complete
#  [                  0%                  ]  445 of 217120 complete
#  [                  0%                  ]  446 of 217120 complete
#  [                  0%                  ]  447 of 217120 complete
#  [                  0%                  ]  448 of 217120 complete
#  [                  0%                  ]  449 of 217120 complete
#  [                  0%                  ]  450 of 217120 complete
#  [                  0%                  ]  451 of 217120 complete
#  [                  0%                  ]  452 of 217120 complete
#  [                  0%                  ]  453 of 217120 complete
#  [                  0%                  ]  454 of 217120 complete
#  [                  0%                  ]  455 of 217120 complete
#  [                  0%                  ]  456 of 217120 complete
#  [                  0%                  ]  457 of 217120 complete
#  [                  0%                  ]  458 of 217120 complete
#  [                  0%                  ]  459 of 217120 complete
#  [                  0%                  ]  460 of 217120 complete
#  [                  0%                  ]  461 of 217120 complete
#  [                  0%                  ]  462 of 217120 complete
#  [                  0%                  ]  463 of 217120 complete
#  [                  0%                  ]  464 of 217120 complete
#  [                  0%                  ]  465 of 217120 complete
#  [                  0%                  ]  466 of 217120 complete
#  [                  0%                  ]  467 of 217120 complete
#  [                  0%                  ]  468 of 217120 complete
#  [                  0%                  ]  469 of 217120 complete
#  [                  0%                  ]  470 of 217120 complete
#  [                  0%                  ]  471 of 217120 complete
#  [                  0%                  ]  472 of 217120 complete
#  [                  0%                  ]  473 of 217120 complete
#  [                  0%                  ]  474 of 217120 complete
#  [                  0%                  ]  475 of 217120 complete
#  [                  0%                  ]  476 of 217120 complete
#  [                  0%                  ]  477 of 217120 complete
#  [                  0%                  ]  478 of 217120 complete
#  [                  0%                  ]  479 of 217120 complete
#  [                  0%                  ]  480 of 217120 complete
#  [                  0%                  ]  481 of 217120 complete
#  [                  0%                  ]  482 of 217120 complete
#  [                  0%                  ]  483 of 217120 complete
#  [                  0%                  ]  484 of 217120 complete
#  [                  0%                  ]  485 of 217120 complete
#  [                  0%                  ]  486 of 217120 complete
#  [                  0%                  ]  487 of 217120 complete
#  [                  0%                  ]  488 of 217120 complete
#  [                  0%                  ]  489 of 217120 complete
#  [                  0%                  ]  490 of 217120 complete
#  [                  0%                  ]  491 of 217120 complete
#  [                  0%                  ]  492 of 217120 complete
#  [                  0%                  ]  493 of 217120 complete
#  [                  0%                  ]  494 of 217120 complete
#  [                  0%                  ]  495 of 217120 complete
#  [                  0%                  ]  496 of 217120 complete
#  [                  0%                  ]  497 of 217120 complete
#  [                  0%                  ]  498 of 217120 complete
#  [                  0%                  ]  499 of 217120 complete
#  [                  0%                  ]  500 of 217120 complete
#  [                  0%                  ]  501 of 217120 complete
#  [                  0%                  ]  502 of 217120 complete
#  [                  0%                  ]  503 of 217120 complete
#  [                  0%                  ]  504 of 217120 complete
#  [                  0%                  ]  505 of 217120 complete
#  [                  0%                  ]  506 of 217120 complete
#  [                  0%                  ]  507 of 217120 complete
#  [                  0%                  ]  508 of 217120 complete
#  [                  0%                  ]  509 of 217120 complete
#  [                  0%                  ]  510 of 217120 complete
#  [                  0%                  ]  511 of 217120 complete
#  [                  0%                  ]  512 of 217120 complete
#  [                  0%                  ]  513 of 217120 complete
#  [                  0%                  ]  514 of 217120 complete
#  [                  0%                  ]  515 of 217120 complete
#  [                  0%                  ]  516 of 217120 complete
#  [                  0%                  ]  517 of 217120 complete
#  [                  0%                  ]  518 of 217120 complete
#  [                  0%                  ]  519 of 217120 complete
#  [                  0%                  ]  520 of 217120 complete
#  [                  0%                  ]  521 of 217120 complete
#  [                  0%                  ]  522 of 217120 complete
#  [                  0%                  ]  523 of 217120 complete
#  [                  0%                  ]  524 of 217120 complete
#  [                  0%                  ]  525 of 217120 complete
#  [                  0%                  ]  526 of 217120 complete
#  [                  0%                  ]  527 of 217120 complete
#  [                  0%                  ]  528 of 217120 complete
#  [                  0%                  ]  529 of 217120 complete
#  [                  0%                  ]  530 of 217120 complete
#  [                  0%                  ]  531 of 217120 complete
#  [                  0%                  ]  532 of 217120 complete
#  [                  0%                  ]  533 of 217120 complete
#  [                  0%                  ]  534 of 217120 complete
#  [                  0%                  ]  535 of 217120 complete
#  [                  0%                  ]  536 of 217120 complete
#  [                  0%                  ]  537 of 217120 complete
#  [                  0%                  ]  538 of 217120 complete
#  [                  0%                  ]  539 of 217120 complete
#  [                  0%                  ]  540 of 217120 complete
#  [                  0%                  ]  541 of 217120 complete
#  [                  0%                  ]  542 of 217120 complete
#  [                  0%                  ]  543 of 217120 complete
#  [                  0%                  ]  544 of 217120 complete
#  [                  0%                  ]  545 of 217120 complete
#  [                  0%                  ]  546 of 217120 complete
#  [                  0%                  ]  547 of 217120 complete
#  [                  0%                  ]  548 of 217120 complete
#  [                  0%                  ]  549 of 217120 complete
#  [                  0%                  ]  550 of 217120 complete
#  [                  0%                  ]  551 of 217120 complete
#  [                  0%                  ]  552 of 217120 complete
#  [                  0%                  ]  553 of 217120 complete
#  [                  0%                  ]  554 of 217120 complete
#  [                  0%                  ]  555 of 217120 complete
#  [                  0%                  ]  556 of 217120 complete
#  [                  0%                  ]  557 of 217120 complete
#  [                  0%                  ]  558 of 217120 complete
#  [                  0%                  ]  559 of 217120 complete
#  [                  0%                  ]  560 of 217120 complete
#  [                  0%                  ]  561 of 217120 complete
#  [                  0%                  ]  562 of 217120 complete
#  [                  0%                  ]  563 of 217120 complete
#  [                  0%                  ]  564 of 217120 complete
#  [                  0%                  ]  565 of 217120 complete
#  [                  0%                  ]  566 of 217120 complete
#  [                  0%                  ]  567 of 217120 complete
#  [                  0%                  ]  568 of 217120 complete
#  [                  0%                  ]  569 of 217120 complete
#  [                  0%                  ]  570 of 217120 complete
#  [                  0%                  ]  571 of 217120 complete
#  [                  0%                  ]  572 of 217120 complete
#  [                  0%                  ]  573 of 217120 complete
#  [                  0%                  ]  574 of 217120 complete
#  [                  0%                  ]  575 of 217120 complete
#  [                  0%                  ]  576 of 217120 complete
#  [                  0%                  ]  577 of 217120 complete
#  [                  0%                  ]  578 of 217120 complete
#  [                  0%                  ]  579 of 217120 complete
#  [                  0%                  ]  580 of 217120 complete
#  [                  0%                  ]  581 of 217120 complete
#  [                  0%                  ]  582 of 217120 complete
#  [                  0%                  ]  583 of 217120 complete
#  [                  0%                  ]  584 of 217120 complete
#  [                  0%                  ]  585 of 217120 complete
#  [                  0%                  ]  586 of 217120 complete
#  [                  0%                  ]  587 of 217120 complete
#  [                  0%                  ]  588 of 217120 complete
#  [                  0%                  ]  589 of 217120 complete
#  [                  0%                  ]  590 of 217120 complete
#  [                  0%                  ]  591 of 217120 complete
#  [                  0%                  ]  592 of 217120 complete
#  [                  0%                  ]  593 of 217120 complete
#  [                  0%                  ]  594 of 217120 complete
#  [                  0%                  ]  595 of 217120 complete
#  [                  0%                  ]  596 of 217120 complete
#  [                  0%                  ]  597 of 217120 complete
#  [                  0%                  ]  598 of 217120 complete
#  [                  0%                  ]  599 of 217120 complete
#  [                  0%                  ]  600 of 217120 complete
#  [                  0%                  ]  601 of 217120 complete
#  [                  0%                  ]  602 of 217120 complete
#  [                  0%                  ]  603 of 217120 complete
#  [                  0%                  ]  604 of 217120 complete
#  [                  0%                  ]  605 of 217120 complete
#  [                  0%                  ]  606 of 217120 complete
#  [                  0%                  ]  607 of 217120 complete
#  [                  0%                  ]  608 of 217120 complete
#  [                  0%                  ]  609 of 217120 complete
#  [                  0%                  ]  610 of 217120 complete
#  [                  0%                  ]  611 of 217120 complete
#  [                  0%                  ]  612 of 217120 complete
#  [                  0%                  ]  613 of 217120 complete
#  [                  0%                  ]  614 of 217120 complete
#  [                  0%                  ]  615 of 217120 complete
#  [                  0%                  ]  616 of 217120 complete
#  [                  0%                  ]  617 of 217120 complete
#  [                  0%                  ]  618 of 217120 complete
#  [                  0%                  ]  619 of 217120 complete
#  [                  0%                  ]  620 of 217120 complete
#  [                  0%                  ]  621 of 217120 complete
#  [                  0%                  ]  622 of 217120 complete
#  [                  0%                  ]  623 of 217120 complete
#  [                  0%                  ]  624 of 217120 complete
#  [                  0%                  ]  625 of 217120 complete
#  [                  0%                  ]  626 of 217120 complete
#  [                  0%                  ]  627 of 217120 complete
#  [                  0%                  ]  628 of 217120 complete
#  [                  0%                  ]  629 of 217120 complete
#  [                  0%                  ]  630 of 217120 complete
#  [                  0%                  ]  631 of 217120 complete
#  [                  0%                  ]  632 of 217120 complete
#  [                  0%                  ]  633 of 217120 complete
#  [                  0%                  ]  634 of 217120 complete
#  [                  0%                  ]  635 of 217120 complete
#  [                  0%                  ]  636 of 217120 complete
#  [                  0%                  ]  637 of 217120 complete
#  [                  0%                  ]  638 of 217120 complete
#  [                  0%                  ]  639 of 217120 complete
#  [                  0%                  ]  640 of 217120 complete
#  [                  0%                  ]  641 of 217120 complete
#  [                  0%                  ]  642 of 217120 complete
#  [                  0%                  ]  643 of 217120 complete
#  [                  0%                  ]  644 of 217120 complete
#  [                  0%                  ]  645 of 217120 complete
#  [                  0%                  ]  646 of 217120 complete
#  [                  0%                  ]  647 of 217120 complete
#  [                  0%                  ]  648 of 217120 complete
#  [                  0%                  ]  649 of 217120 complete
#  [                  0%                  ]  650 of 217120 complete
#  [                  0%                  ]  651 of 217120 complete
#  [                  0%                  ]  652 of 217120 complete
#  [                  0%                  ]  653 of 217120 complete
#  [                  0%                  ]  654 of 217120 complete
#  [                  0%                  ]  655 of 217120 complete
#  [                  0%                  ]  656 of 217120 complete
#  [                  0%                  ]  657 of 217120 complete
#  [                  0%                  ]  658 of 217120 complete
#  [                  0%                  ]  659 of 217120 complete
#  [                  0%                  ]  660 of 217120 complete
#  [                  0%                  ]  661 of 217120 complete
#  [                  0%                  ]  662 of 217120 complete
#  [                  0%                  ]  663 of 217120 complete
#  [                  0%                  ]  664 of 217120 complete
#  [                  0%                  ]  665 of 217120 complete
#  [                  0%                  ]  666 of 217120 complete
#  [                  0%                  ]  667 of 217120 complete
#  [                  0%                  ]  668 of 217120 complete
#  [                  0%                  ]  669 of 217120 complete
#  [                  0%                  ]  670 of 217120 complete
#  [                  0%                  ]  671 of 217120 complete
#  [                  0%                  ]  672 of 217120 complete
#  [                  0%                  ]  673 of 217120 complete
#  [                  0%                  ]  674 of 217120 complete
#  [                  0%                  ]  675 of 217120 complete
#  [                  0%                  ]  676 of 217120 complete
#  [                  0%                  ]  677 of 217120 complete
#  [                  0%                  ]  678 of 217120 complete
#  [                  0%                  ]  679 of 217120 complete
#  [                  0%                  ]  680 of 217120 complete
#  [                  0%                  ]  681 of 217120 complete
#  [                  0%                  ]  682 of 217120 complete
#  [                  0%                  ]  683 of 217120 complete
#  [                  0%                  ]  684 of 217120 complete
#  [                  0%                  ]  685 of 217120 complete
#  [                  0%                  ]  686 of 217120 complete
#  [                  0%                  ]  687 of 217120 complete
#  [                  0%                  ]  688 of 217120 complete
#  [                  0%                  ]  689 of 217120 complete
#  [                  0%                  ]  690 of 217120 complete
#  [                  0%                  ]  691 of 217120 complete
#  [                  0%                  ]  692 of 217120 complete
#  [                  0%                  ]  693 of 217120 complete
#  [                  0%                  ]  694 of 217120 complete
#  [                  0%                  ]  695 of 217120 complete
#  [                  0%                  ]  696 of 217120 complete
#  [                  0%                  ]  697 of 217120 complete
#  [                  0%                  ]  698 of 217120 complete
#  [                  0%                  ]  699 of 217120 complete
#  [                  0%                  ]  700 of 217120 complete
#  [                  0%                  ]  701 of 217120 complete
#  [                  0%                  ]  702 of 217120 complete
#  [                  0%                  ]  703 of 217120 complete
#  [                  0%                  ]  704 of 217120 complete
#  [                  0%                  ]  705 of 217120 complete
#  [                  0%                  ]  706 of 217120 complete
#  [                  0%                  ]  707 of 217120 complete
#  [                  0%                  ]  708 of 217120 complete
#  [                  0%                  ]  709 of 217120 complete
#  [                  0%                  ]  710 of 217120 complete
#  [                  0%                  ]  711 of 217120 complete
#  [                  0%                  ]  712 of 217120 complete
#  [                  0%                  ]  713 of 217120 complete
#  [                  0%                  ]  714 of 217120 complete
#  [                  0%                  ]  715 of 217120 complete
#  [                  0%                  ]  716 of 217120 complete
#  [                  0%                  ]  717 of 217120 complete
#  [                  0%                  ]  718 of 217120 complete
#  [                  0%                  ]  719 of 217120 complete
#  [                  0%                  ]  720 of 217120 complete
#  [                  0%                  ]  721 of 217120 complete
#  [                  0%                  ]  722 of 217120 complete
#  [                  0%                  ]  723 of 217120 complete
#  [                  0%                  ]  724 of 217120 complete
#  [                  0%                  ]  725 of 217120 complete
#  [                  0%                  ]  726 of 217120 complete
#  [                  0%                  ]  727 of 217120 complete
#  [                  0%                  ]  728 of 217120 complete
#  [                  0%                  ]  729 of 217120 complete
# ...
#  [*                 3%                  ]  7391 of 217120 complete
#  [*                 3%                  ]  7392 of 217120 complete
#  [*                 3%                  ]  7393 of 217120 complete
#  [*                 3%                  ]  7394 of 217120 complete
#  [*                 3%                  ]  7395 of 217120 complete
#  [*                 3%                  ]  7396 of 217120 complete
#  [*                 3%                  ]  7397 of 217120 complete
#  [*                 3%                  ]  7398 of 217120 complete
#  [*                 3%                  ]  7399 of 217120 complete
#  [*                 3%                  ]  7400 of 217120 complete
#  [*                 3%                  ]  7401 of 217120 complete
#  [*                 3%                  ]  7402 of 217120 complete
#  [*                 3%                  ]  7403 of 217120 complete
#  [*                 3%                  ]  7404 of 217120 complete
#  [*                 3%                  ]  7405 of 217120 complete
#  [*                 3%                  ]  7406 of 217120 complete
#  [*                 3%                  ]  7407 of 217120 complete
#  [*                 3%                  ]  7408 of 217120 complete
#  [*                 3%                  ]  7409 of 217120 complete
#  [*                 3%                  ]  7410 of 217120 complete
#  [*                 3%                  ]  7411 of 217120 complete
#  [*                 3%                  ]  7412 of 217120 complete
#  [*                 3%                  ]  7413 of 217120 complete
#  [*                 3%                  ]  7414 of 217120 complete
#  [*                 3%                  ]  7415 of 217120 complete
#  [*                 3%                  ]  7416 of 217120 complete
#  [*                 3%                  ]  7417 of 217120 complete
#  [*                 3%                  ]  7418 of 217120 complete
#  [*                 3%                  ]  7419 of 217120 complete
#  [*                 3%                  ]  7420 of 217120 complete
#  [*                 3%                  ]  7421 of 217120 complete
#  [*                 3%                  ]  7422 of 217120 complete
#  [*                 3%                  ]  7423 of 217120 complete
#  [*                 3%                  ]  7424 of 217120 complete
#  [*                 3%                  ]  7425 of 217120 complete
#  [*                 3%                  ]  7426 of 217120 complete
#  [*                 3%                  ]  7427 of 217120 complete
#  [*                 3%                  ]  7428 of 217120 complete
#  [*                 3%                  ]  7429 of 217120 complete
#  [*                 3%                  ]  7430 of 217120 complete
#  [*                 3%                  ]  7431 of 217120 complete
#  [*                 3%                  ]  7432 of 217120 complete
#  [*                 3%                  ]  7433 of 217120 complete
#  [*                 3%                  ]  7434 of 217120 complete
#  [*                 3%                  ]  7435 of 217120 complete
#  [*                 3%                  ]  7436 of 217120 complete
#  [*                 3%                  ]  7437 of 217120 complete
#  [*                 3%                  ]  7438 of 217120 complete
#  [*                 3%                  ]  7439 of 217120 complete
#  [*                 3%                  ]  7440 of 217120 complete
#  [*                 3%                  ]  7441 of 217120 complete
#  [*                 3%                  ]  7442 of 217120 complete
#  [*                 3%                  ]  7443 of 217120 complete
#  [*                 3%                  ]  7444 of 217120 complete
#  [*                 3%                  ]  7445 of 217120 complete
#  [*                 3%                  ]  7446 of 217120 complete
#  [*                 3%                  ]  7447 of 217120 complete
#  [*                 3%                  ]  7448 of 217120 complete
#  [*                 3%                  ]  7449 of 217120 complete
#  [*                 3%                  ]  7450 of 217120 complete
#  [*                 3%                  ]  7451 of 217120 complete
#  [*                 3%                  ]  7452 of 217120 complete
#  [*                 3%                  ]  7453 of 217120 complete
#  [*                 3%                  ]  7454 of 217120 complete
#  [*                 3%                  ]  7455 of 217120 complete
#  [*                 3%                  ]  7456 of 217120 complete
#  [*                 3%                  ]  7457 of 217120 complete
#  [*                 3%                  ]  7458 of 217120 complete
#  [*                 3%                  ]  7459 of 217120 complete
#  [*                 3%                  ]  7460 of 217120 complete
#  [*                 3%                  ]  7461 of 217120 complete
#  [*                 3%                  ]  7462 of 217120 complete
#  [*                 3%                  ]  7463 of 217120 complete
#  [*                 3%                  ]  7464 of 217120 complete
#  [*                 3%                  ]  7465 of 217120 complete
#  [*                 3%                  ]  7466 of 217120 complete
#  [*                 3%                  ]  7467 of 217120 complete
#  [*                 3%                  ]  7468 of 217120 complete
#  [*                 3%                  ]  7469 of 217120 complete
#  [*                 3%                  ]  7470 of 217120 complete
#  [*                 3%                  ]  7471 of 217120 complete
#  [*                 3%                  ]  7472 of 217120 complete
#  [*                 3%                  ]  7473 of 217120 complete
#  [*                 3%                  ]  7474 of 217120 complete
#  [*                 3%                  ]  7475 of 217120 complete
#  [*                 3%                  ]  7476 of 217120 complete
#  [*                 3%                  ]  7477 of 217120 complete
#  [*                 3%                  ]  7478 of 217120 complete
#  [*                 3%                  ]  7479 of 217120 complete
#  [*                 3%                  ]  7480 of 217120 complete
#  [*                 3%                  ]  7481 of 217120 complete
#  [*                 3%                  ]  7482 of 217120 complete
#  [*                 3%                  ]  7483 of 217120 complete
#  [*                 3%                  ]  7484 of 217120 complete
#  [*                 3%                  ]  7485 of 217120 complete
#  [*                 3%                  ]  7486 of 217120 complete
#  [*                 3%                  ]  7487 of 217120 complete
#  [*                 3%                  ]  7488 of 217120 complete
#  [*                 3%                  ]  7489 of 217120 complete
#  [*                 3%                  ]  7490 of 217120 complete
#  [*                 3%                  ]  7491 of 217120 complete
#  [*                 3%                  ]  7492 of 217120 complete
#  [*                 3%                  ]  7493 of 217120 complete
#  [*                 3%                  ]  7494 of 217120 complete
#  [*                 3%                  ]  7495 of 217120 complete
#  [*                 3%                  ]  7496 of 217120 complete
#  [*                 3%                  ]  7497 of 217120 complete
#  [*                 3%                  ]  7498 of 217120 complete
#  [*                 3%                  ]  7499 of 217120 complete
#  [*                 3%                  ]  7500 of 217120 complete
#  [*                 3%                  ]  7501 of 217120 complete
#  [*                 3%                  ]  7502 of 217120 complete
#  [*                 3%                  ]  7503 of 217120 complete
#  [*                 3%                  ]  7504 of 217120 complete
#  [*                 3%                  ]  7505 of 217120 complete
#  [*                 3%                  ]  7506 of 217120 complete
#  [*                 3%                  ]  7507 of 217120 complete
#  [*                 3%                  ]  7508 of 217120 complete
#  [*                 3%                  ]  7509 of 217120 complete
#  [*                 3%                  ]  7510 of 217120 complete
#  [*                 3%                  ]  7511 of 217120 complete
#  [*                 3%                  ]  7512 of 217120 complete
#  [*                 3%                  ]  7513 of 217120 complete
#  [*                 3%                  ]  7514 of 217120 complete
#  [*                 3%                  ]  7515 of 217120 complete
#  [*                 3%                  ]  7516 of 217120 complete
#  [*                 3%                  ]  7517 of 217120 complete
#  [*                 3%                  ]  7518 of 217120 complete
#  [*                 3%                  ]  7519 of 217120 complete
#  [*                 3%                  ]  7520 of 217120 complete
#  [*                 3%                  ]  7521 of 217120 complete
#  [*                 3%                  ]  7522 of 217120 complete
#  [*                 3%                  ]  7523 of 217120 complete
#  [*                 3%                  ]  7524 of 217120 complete
#  [*                 3%                  ]  7525 of 217120 complete
#  [*                 3%                  ]  7526 of 217120 complete
#  [*                 3%                  ]  7527 of 217120 complete
#  [*                 3%                  ]  7528 of 217120 complete
#  [*                 3%                  ]  7529 of 217120 complete
#  [*                 3%                  ]  7530 of 217120 complete
#  [*                 3%                  ]  7531 of 217120 complete
#  [*                 3%                  ]  7532 of 217120 complete
#  [*                 3%                  ]  7533 of 217120 complete
#  [*                 3%                  ]  7534 of 217120 complete
#  [*                 3%                  ]  7535 of 217120 complete
#  [*                 3%                  ]  7536 of 217120 complete
#  [*                 3%                  ]  7537 of 217120 complete
#  [*                 3%                  ]  7538 of 217120 complete
#  [*                 3%                  ]  7539 of 217120 complete
#  [*                 3%                  ]  7540 of 217120 complete
#  [*                 3%                  ]  7541 of 217120 complete
#  [*                 3%                  ]  7542 of 217120 complete
#  [*                 3%                  ]  7543 of 217120 complete
#  [*                 3%                  ]  7544 of 217120 complete
#  [*                 3%                  ]  7545 of 217120 complete
#  [*                 3%                  ]  7546 of 217120 complete
#  [*                 3%                  ]  7547 of 217120 complete
#  [*                 3%                  ]  7548 of 217120 complete
#  [*                 3%                  ]  7549 of 217120 complete
#  [*                 3%                  ]  7550 of 217120 complete
#  [*                 3%                  ]  7551 of 217120 complete
#  [*                 3%                  ]  7552 of 217120 complete
#  [*                 3%                  ]  7553 of 217120 complete
#  [*                 3%                  ]  7554 of 217120 complete
#  [*                 3%                  ]  7555 of 217120 complete
#  [*                 3%                  ]  7556 of 217120 complete
#  [*                 3%                  ]  7557 of 217120 complete
#  [*                 3%                  ]  7558 of 217120 complete
#  [*                 3%                  ]  7559 of 217120 complete
#  [*                 3%                  ]  7560 of 217120 complete
#  [*                 3%                  ]  7561 of 217120 complete
#  [*                 3%                  ]  7562 of 217120 complete
#  [*                 3%                  ]  7563 of 217120 complete
#  [*                 3%                  ]  7564 of 217120 complete
#  [*                 3%                  ]  7565 of 217120 complete
#  [*                 3%                  ]  7566 of 217120 complete
#  [*                 3%                  ]  7567 of 217120 complete
#  [*                 3%                  ]  7568 of 217120 complete
#  [*                 3%                  ]  7569 of 217120 complete
#  [*                 3%                  ]  7570 of 217120 complete
#  [*                 3%                  ]  7571 of 217120 complete
#  [*                 3%                  ]  7572 of 217120 complete
#  [*                 3%                  ]  7573 of 217120 complete
#  [*                 3%                  ]  7574 of 217120 complete
#  [*                 3%                  ]  7575 of 217120 complete
#  [*                 3%                  ]  7576 of 217120 complete
#  [*                 3%                  ]  7577 of 217120 complete
#  [*                 3%                  ]  7578 of 217120 complete
#  [*                 3%                  ]  7579 of 217120 complete
#  [*                 3%                  ]  7580 of 217120 complete
#  [*                 3%                  ]  7581 of 217120 complete
#  [*                 3%                  ]  7582 of 217120 complete
#  [*                 3%                  ]  7583 of 217120 complete
#  [*                 3%                  ]  7584 of 217120 complete
#  [*                 3%                  ]  7585 of 217120 complete
#  [*                 3%                  ]  7586 of 217120 complete
#  [*                 3%                  ]  7587 of 217120 complete
#  [*                 3%                  ]  7588 of 217120 complete
#  [*                 3%                  ]  7589 of 217120 complete
#  [*                 3%                  ]  7590 of 217120 complete
#  [*                 3%                  ]  7591 of 217120 complete
#  [*                 3%                  ]  7592 of 217120 complete
#  [*                 3%                  ]  7593 of 217120 complete
#  [*                 3%                  ]  7594 of 217120 complete
#  [*                 3%                  ]  7595 of 217120 complete
#  [*                 3%                  ]  7596 of 217120 complete
#  [*                 3%                  ]  7597 of 217120 complete
#  [*                 3%                  ]  7598 of 217120 complete
#  [*                 3%                  ]  7599 of 217120 complete
#  [**                4%                  ]  7600 of 217120 complete
#  [**                4%                  ]  7601 of 217120 complete
#  [**                4%                  ]  7602 of 217120 complete
#  [**                4%                  ]  7603 of 217120 complete
#  [**                4%                  ]  7604 of 217120 complete
#  [**                4%                  ]  7605 of 217120 complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-2e387a7ccc1b> in <module>()
#       1 m = KnnDtw(n_neighbors=1, max_warping_window=10)
#       2 m.fit(x_train[::10], y_train[::10])
# ----> 3 label, proba = m.predict(x_test[::10])
#
# <ipython-input-11-290578c2e882> in predict(self, x)
#     172         """
#     173
# --> 174         dm = self._dist_matrix(x, self.x)
#     175
#     176         # Identify the k nearest neighbors
#
# <ipython-input-11-290578c2e882> in _dist_matrix(self, x, y)
#     149                 for j in np.arange(0, y_s[0]):
#     150                     dm[i, j] = self._dtw_distance(x[i, ::self.subsample_step],
# --> 151                                                   y[j, ::self.subsample_step])
#     152                     # Update progress bar
#     153                     dm_count += 1
#
# <ipython-input-11-290578c2e882> in _dtw_distance(self, ts_a, ts_b, d)
#      93                             min(N, i + self.max_warping_window)):
#      94                 choices = cost[i - 1, j - 1], cost[i, j-1], cost[i-1, j]
# ---> 95                 cost[i, j] = min(choices) + d(ts_a[i], ts_b[j])
#      96
#      97         # Return DTW distance given window
#
# <ipython-input-11-290578c2e882> in <lambda>(x, y)
#      55         self.l = l
#      56
# ---> 57     def _dtw_distance(self, ts_a, ts_b, d = lambda x,y: abs(x-y)):
#      58         """Returns the DTW similarity distance between two 2-D
#      59         timeseries numpy arrays.
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import classification_report, confusion_matrix
print classification_report(label, y_test[::10],
                            target_names=[l for l in labels.values()])

conf_mat = confusion_matrix(label, y_test[::10])

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(6), [l for l in labels.values()], rotation=90)
_ = plt.yticks(range(6), [l for l in labels.values()])
# Out:
#                     precision    recall  f1-score   support
#
#            WALKING       0.96      0.80      0.87        60
#   WALKING UPSTAIRS       0.85      0.80      0.83        51
# WALKING DOWNSTAIRS       0.68      0.97      0.80        31
#            SITTING       0.78      0.78      0.78        51
#           STANDING       0.84      0.76      0.80        55
#             LAYING       0.90      1.00      0.95        47
#
#        avg / total       0.85      0.84      0.84       295

# %% [markdown]
# The KNN & DTW classifier performed very well across each of the 6 classes. It even beats the best classification rate published by the authors of the HAR paper.
#
# However, this performance comes at a cost. The KNN algorithm is implemented using brute force. So, comparing 500 training observations to 500 test observations results in 250,000 DTW distances to be computed. And each (unconstrained) DTW distance calculation takes over 65K calculations each (256 x 256). This results in 16.3 billion calculations for just 500 x 500 observations.. Clearly not a scalable classification technique!
#
# Performance improvements can be achieved by reducing the `max_warping_window` parameter. However, these gains will not be sufficient to make KNN & DTW a viable classification technique for large or medium sized datasets.

# %%
import time

time_taken = []
windows = [1,2,5,10,50,100,500,1000,5000]

for w in windows:
    begin = time.time()
    
    t = KnnDtw(n_neighbors=1, max_warping_window=w)
    t.fit(x_train[:20], y_train[:20])
    label, proba = t.predict(x_test[:20])
    
    end = time.time()
    time_taken.append(end - begin)

fig = plt.figure(figsize=(12,5))
_ = plt.plot(windows, [t/400. for t in time_taken], lw=4)
plt.title('DTW Execution Time with \nvarying Max Warping Window')
plt.ylabel('Execution Time (seconds)')
plt.xlabel('Max Warping Window')
plt.xscale('log')
# Out:
#  [                  0%                  ]
#  [                  0%                  ]  2 of 400 complete
#  [                  1%                  ]  3 of 400 complete
#  [                  1%                  ]  4 of 400 complete
#  [                  1%                  ]  5 of 400 complete
#  [*                 2%                  ]  6 of 400 complete
#  [*                 2%                  ]  7 of 400 complete
#  [*                 2%                  ]  8 of 400 complete
#  [*                 2%                  ]  9 of 400 complete
#  [*                 2%                  ]  10 of 400 complete
#  [*                 3%                  ]  11 of 400 complete
#  [*                 3%                  ]  12 of 400 complete
#  [*                 3%                  ]  13 of 400 complete
#  [**                4%                  ]  14 of 400 complete
#  [**                4%                  ]  15 of 400 complete
#  [**                4%                  ]  16 of 400 complete
#  [**                4%                  ]  17 of 400 complete
#  [**                4%                  ]  18 of 400 complete
#  [**                5%                  ]  19 of 400 complete
#  [**                5%                  ]  20 of 400 complete
#  [**                5%                  ]  21 of 400 complete
#  [**                6%                  ]  22 of 400 complete
#  [**                6%                  ]  23 of 400 complete
#  [**                6%                  ]  24 of 400 complete
#  [**                6%                  ]  25 of 400 complete
#  [**                6%                  ]  26 of 400 complete
#  [***               7%                  ]  27 of 400 complete
#  [***               7%                  ]  28 of 400 complete
#  [***               7%                  ]  29 of 400 complete
#  [***               8%                  ]  30 of 400 complete
#  [***               8%                  ]  31 of 400 complete
#  [***               8%                  ]  32 of 400 complete
#  [***               8%                  ]  33 of 400 complete
#  [***               8%                  ]  34 of 400 complete
#  [***               9%                  ]  35 of 400 complete
#  [***               9%                  ]  36 of 400 complete
#  [***               9%                  ]  37 of 400 complete
#  [****             10%                  ]  38 of 400 complete
#  [****             10%                  ]  39 of 400 complete
#  [****             10%                  ]  40 of 400 complete
#  [****             10%                  ]  41 of 400 complete
#  [****             10%                  ]  42 of 400 complete
#  [****             11%                  ]  43 of 400 complete
#  [****             11%                  ]  44 of 400 complete
#  [****             11%                  ]  45 of 400 complete
#  [*****            12%                  ]  46 of 400 complete
#  [*****            12%                  ]  47 of 400 complete
#  [*****            12%                  ]  48 of 400 complete
#  [*****            12%                  ]  49 of 400 complete
#  [*****            12%                  ]  50 of 400 complete
#  [*****            13%                  ]  51 of 400 complete
#  [*****            13%                  ]  52 of 400 complete
#  [*****            13%                  ]  53 of 400 complete
#  [*****            14%                  ]  54 of 400 complete
#  [*****            14%                  ]  55 of 400 complete
#  [*****            14%                  ]  56 of 400 complete
#  [*****            14%                  ]  57 of 400 complete
#  [*****            14%                  ]  58 of 400 complete
#  [******           15%                  ]  59 of 400 complete
#  [******           15%                  ]  60 of 400 complete
#  [******           15%                  ]  61 of 400 complete
#  [******           16%                  ]  62 of 400 complete
#  [******           16%                  ]  63 of 400 complete
#  [******           16%                  ]  64 of 400 complete
#  [******           16%                  ]  65 of 400 complete
#  [******           16%                  ]  66 of 400 complete
#  [******           17%                  ]  67 of 400 complete
#  [******           17%                  ]  68 of 400 complete
#  [******           17%                  ]  69 of 400 complete
#  [*******          18%                  ]  70 of 400 complete
#  [*******          18%                  ]  71 of 400 complete
#  [*******          18%                  ]  72 of 400 complete
#  [*******          18%                  ]  73 of 400 complete
#  [*******          18%                  ]  74 of 400 complete
#  [*******          19%                  ]  75 of 400 complete
#  [*******          19%                  ]  76 of 400 complete
#  [*******          19%                  ]  77 of 400 complete
#  [********         20%                  ]  78 of 400 complete
#  [********         20%                  ]  79 of 400 complete
#  [********         20%                  ]  80 of 400 complete
#  [********         20%                  ]  81 of 400 complete
#  [********         20%                  ]  82 of 400 complete
#  [********         21%                  ]  83 of 400 complete
#  [********         21%                  ]  84 of 400 complete
#  [********         21%                  ]  85 of 400 complete
#  [********         22%                  ]  86 of 400 complete
#  [********         22%                  ]  87 of 400 complete
#  [********         22%                  ]  88 of 400 complete
#  [********         22%                  ]  89 of 400 complete
#  [********         22%                  ]  90 of 400 complete
#  [*********        23%                  ]  91 of 400 complete
#  [*********        23%                  ]  92 of 400 complete
#  [*********        23%                  ]  93 of 400 complete
#  [*********        24%                  ]  94 of 400 complete
#  [*********        24%                  ]  95 of 400 complete
#  [*********        24%                  ]  96 of 400 complete
#  [*********        24%                  ]  97 of 400 complete
#  [*********        24%                  ]  98 of 400 complete
#  [**********       25%                  ]  99 of 400 complete
#  [**********       25%                  ]  100 of 400 complete
#  [**********       25%                  ]  101 of 400 complete
#  [**********       26%                  ]  102 of 400 complete
#  [**********       26%                  ]  103 of 400 complete
#  [**********       26%                  ]  104 of 400 complete
#  [**********       26%                  ]  105 of 400 complete
#  [**********       26%                  ]  106 of 400 complete
#  [**********       27%                  ]  107 of 400 complete
#  [**********       27%                  ]  108 of 400 complete
#  [**********       27%                  ]  109 of 400 complete
#  [***********      28%                  ]  110 of 400 complete
#  [***********      28%                  ]  111 of 400 complete
#  [***********      28%                  ]  112 of 400 complete
#  [***********      28%                  ]  113 of 400 complete
#  [***********      28%                  ]  114 of 400 complete
#  [***********      29%                  ]  115 of 400 complete
#  [***********      29%                  ]  116 of 400 complete
#  [***********      29%                  ]  117 of 400 complete
#  [***********      30%                  ]  118 of 400 complete
#  [***********      30%                  ]  119 of 400 complete
#  [***********      30%                  ]  120 of 400 complete
#  [***********      30%                  ]  121 of 400 complete
#  [***********      30%                  ]  122 of 400 complete
#  [************     31%                  ]  123 of 400 complete
#  [************     31%                  ]  124 of 400 complete
#  [************     31%                  ]  125 of 400 complete
#  [************     32%                  ]  126 of 400 complete
#  [************     32%                  ]  127 of 400 complete
#  [************     32%                  ]  128 of 400 complete
#  [************     32%                  ]  129 of 400 complete
#  [************     32%                  ]  130 of 400 complete
#  [*************    33%                  ]  131 of 400 complete
#  [*************    33%                  ]  132 of 400 complete
#  [*************    33%                  ]  133 of 400 complete
#  [*************    34%                  ]  134 of 400 complete
#  [*************    34%                  ]  135 of 400 complete
#  [*************    34%                  ]  136 of 400 complete
#  [*************    34%                  ]  137 of 400 complete
#  [*************    34%                  ]  138 of 400 complete
#  [*************    35%                  ]  139 of 400 complete
#  [*************    35%                  ]  140 of 400 complete
#  [*************    35%                  ]  141 of 400 complete
#  [**************   36%                  ]  142 of 400 complete
#  [**************   36%                  ]  143 of 400 complete
#  [**************   36%                  ]  144 of 400 complete
#  [**************   36%                  ]  145 of 400 complete
#  [**************   36%                  ]  146 of 400 complete
#  [**************   37%                  ]  147 of 400 complete
#  [**************   37%                  ]  148 of 400 complete
#  [**************   37%                  ]  149 of 400 complete
#  [**************   38%                  ]  150 of 400 complete
#  [**************   38%                  ]  151 of 400 complete
#  [**************   38%                  ]  152 of 400 complete
#  [**************   38%                  ]  153 of 400 complete
#  [**************   38%                  ]  154 of 400 complete
#  [***************  39%                  ]  155 of 400 complete
#  [***************  39%                  ]  156 of 400 complete
#  [***************  39%                  ]  157 of 400 complete
#  [***************  40%                  ]  158 of 400 complete
#  [***************  40%                  ]  159 of 400 complete
#  [***************  40%                  ]  160 of 400 complete
#  [***************  40%                  ]  161 of 400 complete
#  [***************  40%                  ]  162 of 400 complete
#  [**************** 41%                  ]  163 of 400 complete
#  [**************** 41%                  ]  164 of 400 complete
#  [**************** 41%                  ]  165 of 400 complete
#  [**************** 42%                  ]  166 of 400 complete
#  [**************** 42%                  ]  167 of 400 complete
#  [**************** 42%                  ]  168 of 400 complete
#  [**************** 42%                  ]  169 of 400 complete
#  [**************** 42%                  ]  170 of 400 complete
#  [**************** 43%                  ]  171 of 400 complete
#  [**************** 43%                  ]  172 of 400 complete
#  [**************** 43%                  ]  173 of 400 complete
#  [*****************44%                  ]  174 of 400 complete
#  [*****************44%                  ]  175 of 400 complete
#  [*****************44%                  ]  176 of 400 complete
#  [*****************44%                  ]  177 of 400 complete
#  [*****************44%                  ]  178 of 400 complete
#  [*****************45%                  ]  179 of 400 complete
#  [*****************45%                  ]  180 of 400 complete
#  [*****************45%                  ]  181 of 400 complete
#  [*****************46%                  ]  182 of 400 complete
#  [*****************46%                  ]  183 of 400 complete
#  [*****************46%                  ]  184 of 400 complete
#  [*****************46%                  ]  185 of 400 complete
#  [*****************46%                  ]  186 of 400 complete
#  [*****************47%                  ]  187 of 400 complete
#  [*****************47%                  ]  188 of 400 complete
#  [*****************47%                  ]  189 of 400 complete
#  [*****************48%                  ]  190 of 400 complete
#  [*****************48%                  ]  191 of 400 complete
#  [*****************48%                  ]  192 of 400 complete
#  [*****************48%                  ]  193 of 400 complete
#  [*****************48%                  ]  194 of 400 complete
#  [*****************49%                  ]  195 of 400 complete
#  [*****************49%                  ]  196 of 400 complete
#  [*****************49%                  ]  197 of 400 complete
#  [*****************50%                  ]  198 of 400 complete
#  [*****************50%                  ]  199 of 400 complete
#  [*****************50%                  ]  200 of 400 complete
#  [*****************50%                  ]  201 of 400 complete
#  [*****************50%                  ]  202 of 400 complete
#  [*****************51%                  ]  203 of 400 complete
#  [*****************51%                  ]  204 of 400 complete
#  [*****************51%                  ]  205 of 400 complete
#  [*****************52%                  ]  206 of 400 complete
#  [*****************52%                  ]  207 of 400 complete
#  [*****************52%                  ]  208 of 400 complete
#  [*****************52%                  ]  209 of 400 complete
#  [*****************52%                  ]  210 of 400 complete
#  [*****************53%                  ]  211 of 400 complete
#  [*****************53%                  ]  212 of 400 complete
#  [*****************53%                  ]  213 of 400 complete
#  [*****************54%*                 ]  214 of 400 complete
#  [*****************54%*                 ]  215 of 400 complete
#  [*****************54%*                 ]  216 of 400 complete
#  [*****************54%*                 ]  217 of 400 complete
#  [*****************55%*                 ]  218 of 400 complete
#  [*****************55%*                 ]  219 of 400 complete
#  [*****************55%*                 ]  220 of 400 complete
#  [*****************55%*                 ]  221 of 400 complete
#  [*****************56%*                 ]  222 of 400 complete
#  [*****************56%*                 ]  223 of 400 complete
#  [*****************56%*                 ]  224 of 400 complete
#  [*****************56%*                 ]  225 of 400 complete
#  [*****************56%*                 ]  226 of 400 complete
#  [*****************57%**                ]  227 of 400 complete
#  [*****************57%**                ]  228 of 400 complete
#  [*****************57%**                ]  229 of 400 complete
#  [*****************57%**                ]  230 of 400 complete
#  [*****************58%**                ]  231 of 400 complete
#  [*****************58%**                ]  232 of 400 complete
#  [*****************58%**                ]  233 of 400 complete
#  [*****************58%**                ]  234 of 400 complete
#  [*****************59%**                ]  235 of 400 complete
#  [*****************59%**                ]  236 of 400 complete
#  [*****************59%**                ]  237 of 400 complete
#  [*****************60%***               ]  238 of 400 complete
#  [*****************60%***               ]  239 of 400 complete
#  [*****************60%***               ]  240 of 400 complete
#  [*****************60%***               ]  241 of 400 complete
#  [*****************60%***               ]  242 of 400 complete
#  [*****************61%***               ]  243 of 400 complete
#  [*****************61%***               ]  244 of 400 complete
#  [*****************61%***               ]  245 of 400 complete
#  [*****************62%****              ]  246 of 400 complete
#  [*****************62%****              ]  247 of 400 complete
#  [*****************62%****              ]  248 of 400 complete
#  [*****************62%****              ]  249 of 400 complete
#  [*****************62%****              ]  250 of 400 complete
#  [*****************63%****              ]  251 of 400 complete
#  [*****************63%****              ]  252 of 400 complete
#  [*****************63%****              ]  253 of 400 complete
#  [*****************64%****              ]  254 of 400 complete
#  [*****************64%****              ]  255 of 400 complete
#  [*****************64%****              ]  256 of 400 complete
#  [*****************64%****              ]  257 of 400 complete
#  [*****************64%****              ]  258 of 400 complete
#  [*****************65%*****             ]  259 of 400 complete
#  [*****************65%*****             ]  260 of 400 complete
#  [*****************65%*****             ]  261 of 400 complete
#  [*****************66%*****             ]  262 of 400 complete
#  [*****************66%*****             ]  263 of 400 complete
#  [*****************66%*****             ]  264 of 400 complete
#  [*****************66%*****             ]  265 of 400 complete
#  [*****************66%*****             ]  266 of 400 complete
#  [*****************67%*****             ]  267 of 400 complete
#  [*****************67%*****             ]  268 of 400 complete
#  [*****************67%*****             ]  269 of 400 complete
#  [*****************68%******            ]  270 of 400 complete
#  [*****************68%******            ]  271 of 400 complete
#  [*****************68%******            ]  272 of 400 complete
#  [*****************68%******            ]  273 of 400 complete
#  [*****************68%******            ]  274 of 400 complete
#  [*****************69%******            ]  275 of 400 complete
#  [*****************69%******            ]  276 of 400 complete
#  [*****************69%******            ]  277 of 400 complete
#  [*****************70%*******           ]  278 of 400 complete
#  [*****************70%*******           ]  279 of 400 complete
#  [*****************70%*******           ]  280 of 400 complete
#  [*****************70%*******           ]  281 of 400 complete
#  [*****************70%*******           ]  282 of 400 complete
#  [*****************71%*******           ]  283 of 400 complete
#  [*****************71%*******           ]  284 of 400 complete
#  [*****************71%*******           ]  285 of 400 complete
#  [*****************72%*******           ]  286 of 400 complete
#  [*****************72%*******           ]  287 of 400 complete
#  [*****************72%*******           ]  288 of 400 complete
#  [*****************72%*******           ]  289 of 400 complete
#  [*****************72%*******           ]  290 of 400 complete
#  [*****************73%********          ]  291 of 400 complete
#  [*****************73%********          ]  292 of 400 complete
#  [*****************73%********          ]  293 of 400 complete
#  [*****************74%********          ]  294 of 400 complete
#  [*****************74%********          ]  295 of 400 complete
#  [*****************74%********          ]  296 of 400 complete
#  [*****************74%********          ]  297 of 400 complete
#  [*****************74%********          ]  298 of 400 complete
#  [*****************75%********          ]  299 of 400 complete
#  [*****************75%********          ]  300 of 400 complete
#  [*****************75%********          ]  301 of 400 complete
#  [*****************76%*********         ]  302 of 400 complete
#  [*****************76%*********         ]  303 of 400 complete
#  [*****************76%*********         ]  304 of 400 complete
#  [*****************76%*********         ]  305 of 400 complete
#  [*****************76%*********         ]  306 of 400 complete
#  [*****************77%*********         ]  307 of 400 complete
#  [*****************77%*********         ]  308 of 400 complete
#  [*****************77%*********         ]  309 of 400 complete
#  [*****************78%**********        ]  310 of 400 complete
#  [*****************78%**********        ]  311 of 400 complete
#  [*****************78%**********        ]  312 of 400 complete
#  [*****************78%**********        ]  313 of 400 complete
#  [*****************78%**********        ]  314 of 400 complete
#  [*****************79%**********        ]  315 of 400 complete
#  [*****************79%**********        ]  316 of 400 complete
#  [*****************79%**********        ]  317 of 400 complete
#  [*****************80%**********        ]  318 of 400 complete
#  [*****************80%**********        ]  319 of 400 complete
#  [*****************80%**********        ]  320 of 400 complete
#  [*****************80%**********        ]  321 of 400 complete
#  [*****************80%**********        ]  322 of 400 complete
#  [*****************81%***********       ]  323 of 400 complete
#  [*****************81%***********       ]  324 of 400 complete
#  [*****************81%***********       ]  325 of 400 complete
#  [*****************82%***********       ]  326 of 400 complete
#  [*****************82%***********       ]  327 of 400 complete
#  [*****************82%***********       ]  328 of 400 complete
#  [*****************82%***********       ]  329 of 400 complete
#  [*****************82%***********       ]  330 of 400 complete
#  [*****************83%************      ]  331 of 400 complete
#  [*****************83%************      ]  332 of 400 complete
#  [*****************83%************      ]  333 of 400 complete
#  [*****************84%************      ]  334 of 400 complete
#  [*****************84%************      ]  335 of 400 complete
#  [*****************84%************      ]  336 of 400 complete
#  [*****************84%************      ]  337 of 400 complete
#  [*****************84%************      ]  338 of 400 complete
#  [*****************85%************      ]  339 of 400 complete
#  [*****************85%************      ]  340 of 400 complete
#  [*****************85%************      ]  341 of 400 complete
#  [*****************86%*************     ]  342 of 400 complete
#  [*****************86%*************     ]  343 of 400 complete
#  [*****************86%*************     ]  344 of 400 complete
#  [*****************86%*************     ]  345 of 400 complete
#  [*****************86%*************     ]  346 of 400 complete
#  [*****************87%*************     ]  347 of 400 complete
#  [*****************87%*************     ]  348 of 400 complete
#  [*****************87%*************     ]  349 of 400 complete
#  [*****************88%*************     ]  350 of 400 complete
#  [*****************88%*************     ]  351 of 400 complete
#  [*****************88%*************     ]  352 of 400 complete
#  [*****************88%*************     ]  353 of 400 complete
#  [*****************88%*************     ]  354 of 400 complete
#  [*****************89%**************    ]  355 of 400 complete
#  [*****************89%**************    ]  356 of 400 complete
#  [*****************89%**************    ]  357 of 400 complete
#  [*****************90%**************    ]  358 of 400 complete
#  [*****************90%**************    ]  359 of 400 complete
#  [*****************90%**************    ]  360 of 400 complete
#  [*****************90%**************    ]  361 of 400 complete
#  [*****************90%**************    ]  362 of 400 complete
#  [*****************91%***************   ]  363 of 400 complete
#  [*****************91%***************   ]  364 of 400 complete
#  [*****************91%***************   ]  365 of 400 complete
#  [*****************92%***************   ]  366 of 400 complete
#  [*****************92%***************   ]  367 of 400 complete
#  [*****************92%***************   ]  368 of 400 complete
#  [*****************92%***************   ]  369 of 400 complete
#  [*****************92%***************   ]  370 of 400 complete
#  [*****************93%***************   ]  371 of 400 complete
#  [*****************93%***************   ]  372 of 400 complete
#  [*****************93%***************   ]  373 of 400 complete
#  [*****************94%****************  ]  374 of 400 complete
#  [*****************94%****************  ]  375 of 400 complete
#  [*****************94%****************  ]  376 of 400 complete
#  [*****************94%****************  ]  377 of 400 complete
#  [*****************94%****************  ]  378 of 400 complete
#  [*****************95%****************  ]  379 of 400 complete
#  [*****************95%****************  ]  380 of 400 complete
#  [*****************95%****************  ]  381 of 400 complete
#  [*****************96%****************  ]  382 of 400 complete
#  [*****************96%****************  ]  383 of 400 complete
#  [*****************96%****************  ]  384 of 400 complete
#  [*****************96%****************  ]  385 of 400 complete
#  [*****************96%****************  ]  386 of 400 complete
#  [*****************97%***************** ]  387 of 400 complete
#  [*****************97%***************** ]  388 of 400 complete
#  [*****************97%***************** ]  389 of 400 complete
#  [*****************98%***************** ]  390 of 400 complete
#  [*****************98%***************** ]  391 of 400 complete
#  [*****************98%***************** ]  392 of 400 complete
#  [*****************98%***************** ]  393 of 400 complete
#  [*****************98%***************** ]  394 of 400 complete
#  [*****************99%******************]  395 of 400 complete
#  [*****************99%******************]  396 of 400 complete
#  [*****************99%******************]  397 of 400 complete
#  [****************100%******************]  398 of 400 complete
#  [****************100%******************]  399 of 400 complete
#  [****************100%******************]  400 of 400 complete
#  [                  0%                  ]
#  [                  0%                  ]  2 of 400 complete
#  [                  1%                  ]  3 of 400 complete
#  [                  1%                  ]  4 of 400 complete
#  [                  1%                  ]  5 of 400 complete
#  [*                 2%                  ]  6 of 400 complete
#  [*                 2%                  ]  7 of 400 complete
#  [*                 2%                  ]  8 of 400 complete
#  [*                 2%                  ]  9 of 400 complete
#  [*                 2%                  ]  10 of 400 complete
#  [*                 3%                  ]  11 of 400 complete
#  [*                 3%                  ]  12 of 400 complete
#  [*                 3%                  ]  13 of 400 complete
#  [**                4%                  ]  14 of 400 complete
#  [**                4%                  ]  15 of 400 complete
#  [**                4%                  ]  16 of 400 complete
#  [**                4%                  ]  17 of 400 complete
#  [**                4%                  ]  18 of 400 complete
#  [**                5%                  ]  19 of 400 complete
#  [**                5%                  ]  20 of 400 complete
#  [**                5%                  ]  21 of 400 complete
#  [**                6%                  ]  22 of 400 complete
#  [**                6%                  ]  23 of 400 complete
#  [**                6%                  ]  24 of 400 complete
#  [**                6%                  ]  25 of 400 complete
#  [**                6%                  ]  26 of 400 complete
#  [***               7%                  ]  27 of 400 complete
#  [***               7%                  ]  28 of 400 complete
#  [***               7%                  ]  29 of 400 complete
#  [***               8%                  ]  30 of 400 complete
#  [***               8%                  ]  31 of 400 complete
#  [***               8%                  ]  32 of 400 complete
#  [***               8%                  ]  33 of 400 complete
#  [***               8%                  ]  34 of 400 complete
#  [***               9%                  ]  35 of 400 complete
#  [***               9%                  ]  36 of 400 complete
#  [***               9%                  ]  37 of 400 complete
#  [****             10%                  ]  38 of 400 complete
#  [****             10%                  ]  39 of 400 complete
#  [****             10%                  ]  40 of 400 complete
#  [****             10%                  ]  41 of 400 complete
#  [****             10%                  ]  42 of 400 complete
#  [****             11%                  ]  43 of 400 complete
#  [****             11%                  ]  44 of 400 complete
#  [****             11%                  ]  45 of 400 complete
#  [*****            12%                  ]  46 of 400 complete
#  [*****            12%                  ]  47 of 400 complete
#  [*****            12%                  ]  48 of 400 complete
#  [*****            12%                  ]  49 of 400 complete
#  [*****            12%                  ]  50 of 400 complete
#  [*****            13%                  ]  51 of 400 complete
#  [*****            13%                  ]  52 of 400 complete
#  [*****            13%                  ]  53 of 400 complete
#  [*****            14%                  ]  54 of 400 complete
#  [*****            14%                  ]  55 of 400 complete
#  [*****            14%                  ]  56 of 400 complete
#  [*****            14%                  ]  57 of 400 complete
#  [*****            14%                  ]  58 of 400 complete
#  [******           15%                  ]  59 of 400 complete
#  [******           15%                  ]  60 of 400 complete
#  [******           15%                  ]  61 of 400 complete
#  [******           16%                  ]  62 of 400 complete
#  [******           16%                  ]  63 of 400 complete
#  [******           16%                  ]  64 of 400 complete
#  [******           16%                  ]  65 of 400 complete
#  [******           16%                  ]  66 of 400 complete
#  [******           17%                  ]  67 of 400 complete
#  [******           17%                  ]  68 of 400 complete
#  [******           17%                  ]  69 of 400 complete
#  [*******          18%                  ]  70 of 400 complete
#  [*******          18%                  ]  71 of 400 complete
#  [*******          18%                  ]  72 of 400 complete
#  [*******          18%                  ]  73 of 400 complete
#  [*******          18%                  ]  74 of 400 complete
#  [*******          19%                  ]  75 of 400 complete
#  [*******          19%                  ]  76 of 400 complete
#  [*******          19%                  ]  77 of 400 complete
#  [********         20%                  ]  78 of 400 complete
#  [********         20%                  ]  79 of 400 complete
#  [********         20%                  ]  80 of 400 complete
#  [********         20%                  ]  81 of 400 complete
#  [********         20%                  ]  82 of 400 complete
#  [********         21%                  ]  83 of 400 complete
#  [********         21%                  ]  84 of 400 complete
#  [********         21%                  ]  85 of 400 complete
#  [********         22%                  ]  86 of 400 complete
#  [********         22%                  ]  87 of 400 complete
#  [********         22%                  ]  88 of 400 complete
#  [********         22%                  ]  89 of 400 complete
#  [********         22%                  ]  90 of 400 complete
#  [*********        23%                  ]  91 of 400 complete
#  [*********        23%                  ]  92 of 400 complete
#  [*********        23%                  ]  93 of 400 complete
#  [*********        24%                  ]  94 of 400 complete
#  [*********        24%                  ]  95 of 400 complete
#  [*********        24%                  ]  96 of 400 complete
#  [*********        24%                  ]  97 of 400 complete
#  [*********        24%                  ]  98 of 400 complete
#  [**********       25%                  ]  99 of 400 complete
#  [**********       25%                  ]  100 of 400 complete
#  [**********       25%                  ]  101 of 400 complete
#  [**********       26%                  ]  102 of 400 complete
#  [**********       26%                  ]  103 of 400 complete
#  [**********       26%                  ]  104 of 400 complete
#  [**********       26%                  ]  105 of 400 complete
#  [**********       26%                  ]  106 of 400 complete
#  [**********       27%                  ]  107 of 400 complete
#  [**********       27%                  ]  108 of 400 complete
#  [**********       27%                  ]  109 of 400 complete
#  [***********      28%                  ]  110 of 400 complete
#  [***********      28%                  ]  111 of 400 complete
#  [***********      28%                  ]  112 of 400 complete
#  [***********      28%                  ]  113 of 400 complete
#  [***********      28%                  ]  114 of 400 complete
#  [***********      29%                  ]  115 of 400 complete
#  [***********      29%                  ]  116 of 400 complete
#  [***********      29%                  ]  117 of 400 complete
#  [***********      30%                  ]  118 of 400 complete
#  [***********      30%                  ]  119 of 400 complete
#  [***********      30%                  ]  120 of 400 complete
#  [***********      30%                  ]  121 of 400 complete
#  [***********      30%                  ]  122 of 400 complete
#  [************     31%                  ]  123 of 400 complete
#  [************     31%                  ]  124 of 400 complete
#  [************     31%                  ]  125 of 400 complete
#  [************     32%                  ]  126 of 400 complete
#  [************     32%                  ]  127 of 400 complete
#  [************     32%                  ]  128 of 400 complete
#  [************     32%                  ]  129 of 400 complete
#  [************     32%                  ]  130 of 400 complete
#  [*************    33%                  ]  131 of 400 complete
#  [*************    33%                  ]  132 of 400 complete
#  [*************    33%                  ]  133 of 400 complete
#  [*************    34%                  ]  134 of 400 complete
#  [*************    34%                  ]  135 of 400 complete
#  [*************    34%                  ]  136 of 400 complete
#  [*************    34%                  ]  137 of 400 complete
#  [*************    34%                  ]  138 of 400 complete
#  [*************    35%                  ]  139 of 400 complete
#  [*************    35%                  ]  140 of 400 complete
#  [*************    35%                  ]  141 of 400 complete
#  [**************   36%                  ]  142 of 400 complete
#  [**************   36%                  ]  143 of 400 complete
#  [**************   36%                  ]  144 of 400 complete
#  [**************   36%                  ]  145 of 400 complete
#  [**************   36%                  ]  146 of 400 complete
#  [**************   37%                  ]  147 of 400 complete
#  [**************   37%                  ]  148 of 400 complete
#  [**************   37%                  ]  149 of 400 complete
#  [**************   38%                  ]  150 of 400 complete
#  [**************   38%                  ]  151 of 400 complete
#  [**************   38%                  ]  152 of 400 complete
#  [**************   38%                  ]  153 of 400 complete
#  [**************   38%                  ]  154 of 400 complete
#  [***************  39%                  ]  155 of 400 complete
#  [***************  39%                  ]  156 of 400 complete
#  [***************  39%                  ]  157 of 400 complete
#  [***************  40%                  ]  158 of 400 complete
#  [***************  40%                  ]  159 of 400 complete
#  [***************  40%                  ]  160 of 400 complete
#  [***************  40%                  ]  161 of 400 complete
#  [***************  40%                  ]  162 of 400 complete
#  [**************** 41%                  ]  163 of 400 complete
#  [**************** 41%                  ]  164 of 400 complete
#  [**************** 41%                  ]  165 of 400 complete
#  [**************** 42%                  ]  166 of 400 complete
#  [**************** 42%                  ]  167 of 400 complete
#  [**************** 42%                  ]  168 of 400 complete
#  [**************** 42%                  ]  169 of 400 complete
#  [**************** 42%                  ]  170 of 400 complete
#  [**************** 43%                  ]  171 of 400 complete
#  [**************** 43%                  ]  172 of 400 complete
#  [**************** 43%                  ]  173 of 400 complete
#  [*****************44%                  ]  174 of 400 complete
#  [*****************44%                  ]  175 of 400 complete
#  [*****************44%                  ]  176 of 400 complete
#  [*****************44%                  ]  177 of 400 complete
#  [*****************44%                  ]  178 of 400 complete
#  [*****************45%                  ]  179 of 400 complete
#  [*****************45%                  ]  180 of 400 complete
#  [*****************45%                  ]  181 of 400 complete
#  [*****************46%                  ]  182 of 400 complete
#  [*****************46%                  ]  183 of 400 complete
#  [*****************46%                  ]  184 of 400 complete
#  [*****************46%                  ]  185 of 400 complete
#  [*****************46%                  ]  186 of 400 complete
#  [*****************47%                  ]  187 of 400 complete
#  [*****************47%                  ]  188 of 400 complete
#  [*****************47%                  ]  189 of 400 complete
#  [*****************48%                  ]  190 of 400 complete
#  [*****************48%                  ]  191 of 400 complete
#  [*****************48%                  ]  192 of 400 complete
#  [*****************48%                  ]  193 of 400 complete
#  [*****************48%                  ]  194 of 400 complete
#  [*****************49%                  ]  195 of 400 complete
#  [*****************49%                  ]  196 of 400 complete
#  [*****************49%                  ]  197 of 400 complete
#  [*****************50%                  ]  198 of 400 complete
#  [*****************50%                  ]  199 of 400 complete
#  [*****************50%                  ]  200 of 400 complete
#  [*****************50%                  ]  201 of 400 complete
#  [*****************50%                  ]  202 of 400 complete
#  [*****************51%                  ]  203 of 400 complete
#  [*****************51%                  ]  204 of 400 complete
#  [*****************51%                  ]  205 of 400 complete
#  [*****************52%                  ]  206 of 400 complete
#  [*****************52%                  ]  207 of 400 complete
#  [*****************52%                  ]  208 of 400 complete
#  [*****************52%                  ]  209 of 400 complete
#  [*****************52%                  ]  210 of 400 complete
#  [*****************53%                  ]  211 of 400 complete
#  [*****************53%                  ]  212 of 400 complete
#  [*****************53%                  ]  213 of 400 complete
#  [*****************54%*                 ]  214 of 400 complete
#  [*****************54%*                 ]  215 of 400 complete
#  [*****************54%*                 ]  216 of 400 complete
#  [*****************54%*                 ]  217 of 400 complete
#  [*****************55%*                 ]  218 of 400 complete
#  [*****************55%*                 ]  219 of 400 complete
#  [*****************55%*                 ]  220 of 400 complete
#  [*****************55%*                 ]  221 of 400 complete
#  [*****************56%*                 ]  222 of 400 complete
#  [*****************56%*                 ]  223 of 400 complete
#  [*****************56%*                 ]  224 of 400 complete
#  [*****************56%*                 ]  225 of 400 complete
#  [*****************56%*                 ]  226 of 400 complete
#  [*****************57%**                ]  227 of 400 complete
#  [*****************57%**                ]  228 of 400 complete
#  [*****************57%**                ]  229 of 400 complete
#  [*****************57%**                ]  230 of 400 complete
#  [*****************58%**                ]  231 of 400 complete
#  [*****************58%**                ]  232 of 400 complete
#  [*****************58%**                ]  233 of 400 complete
#  [*****************58%**                ]  234 of 400 complete
#  [*****************59%**                ]  235 of 400 complete
#  [*****************59%**                ]  236 of 400 complete
#  [*****************59%**                ]  237 of 400 complete
#  [*****************60%***               ]  238 of 400 complete
#  [*****************60%***               ]  239 of 400 complete
#  [*****************60%***               ]  240 of 400 complete
#  [*****************60%***               ]  241 of 400 complete
#  [*****************60%***               ]  242 of 400 complete
#  [*****************61%***               ]  243 of 400 complete
#  [*****************61%***               ]  244 of 400 complete
#  [*****************61%***               ]  245 of 400 complete
#  [*****************62%****              ]  246 of 400 complete
#  [*****************62%****              ]  247 of 400 complete
#  [*****************62%****              ]  248 of 400 complete
#  [*****************62%****              ]  249 of 400 complete
#  [*****************62%****              ]  250 of 400 complete
#  [*****************63%****              ]  251 of 400 complete
#  [*****************63%****              ]  252 of 400 complete
#  [*****************63%****              ]  253 of 400 complete
#  [*****************64%****              ]  254 of 400 complete
#  [*****************64%****              ]  255 of 400 complete
#  [*****************64%****              ]  256 of 400 complete
#  [*****************64%****              ]  257 of 400 complete
#  [*****************64%****              ]  258 of 400 complete
#  [*****************65%*****             ]  259 of 400 complete
#  [*****************65%*****             ]  260 of 400 complete
#  [*****************65%*****             ]  261 of 400 complete
#  [*****************66%*****             ]  262 of 400 complete
#  [*****************66%*****             ]  263 of 400 complete
#  [*****************66%*****             ]  264 of 400 complete
#  [*****************66%*****             ]  265 of 400 complete
#  [*****************66%*****             ]  266 of 400 complete
#  [*****************67%*****             ]  267 of 400 complete
#  [*****************67%*****             ]  268 of 400 complete
#  [*****************67%*****             ]  269 of 400 complete
#  [*****************68%******            ]  270 of 400 complete
#  [*****************68%******            ]  271 of 400 complete
#  [*****************68%******            ]  272 of 400 complete
#  [*****************68%******            ]  273 of 400 complete
#  [*****************68%******            ]  274 of 400 complete
#  [*****************69%******            ]  275 of 400 complete
#  [*****************69%******            ]  276 of 400 complete
#  [*****************69%******            ]  277 of 400 complete
#  [*****************70%*******           ]  278 of 400 complete
#  [*****************70%*******           ]  279 of 400 complete
#  [*****************70%*******           ]  280 of 400 complete
#  [*****************70%*******           ]  281 of 400 complete
#  [*****************70%*******           ]  282 of 400 complete
#  [*****************71%*******           ]  283 of 400 complete
#  [*****************71%*******           ]  284 of 400 complete
#  [*****************71%*******           ]  285 of 400 complete
#  [*****************72%*******           ]  286 of 400 complete
#  [*****************72%*******           ]  287 of 400 complete
#  [*****************72%*******           ]  288 of 400 complete
#  [*****************72%*******           ]  289 of 400 complete
#  [*****************72%*******           ]  290 of 400 complete
#  [*****************73%********          ]  291 of 400 complete
#  [*****************73%********          ]  292 of 400 complete
#  [*****************73%********          ]  293 of 400 complete
#  [*****************74%********          ]  294 of 400 complete
#  [*****************74%********          ]  295 of 400 complete
#  [*****************74%********          ]  296 of 400 complete
#  [*****************74%********          ]  297 of 400 complete
#  [*****************74%********          ]  298 of 400 complete
#  [*****************75%********          ]  299 of 400 complete
#  [*****************75%********          ]  300 of 400 complete
#  [*****************75%********          ]  301 of 400 complete
#  [*****************76%*********         ]  302 of 400 complete
#  [*****************76%*********         ]  303 of 400 complete
#  [*****************76%*********         ]  304 of 400 complete
#  [*****************76%*********         ]  305 of 400 complete
#  [*****************76%*********         ]  306 of 400 complete
#  [*****************77%*********         ]  307 of 400 complete
#  [*****************77%*********         ]  308 of 400 complete
#  [*****************77%*********         ]  309 of 400 complete
#  [*****************78%**********        ]  310 of 400 complete
#  [*****************78%**********        ]  311 of 400 complete
#  [*****************78%**********        ]  312 of 400 complete
#  [*****************78%**********        ]  313 of 400 complete
#  [*****************78%**********        ]  314 of 400 complete
#  [*****************79%**********        ]  315 of 400 complete
#  [*****************79%**********        ]  316 of 400 complete
#  [*****************79%**********        ]  317 of 400 complete
#  [*****************80%**********        ]  318 of 400 complete
#  [*****************80%**********        ]  319 of 400 complete
#  [*****************80%**********        ]  320 of 400 complete
#  [*****************80%**********        ]  321 of 400 complete
#  [*****************80%**********        ]  322 of 400 complete
#  [*****************81%***********       ]  323 of 400 complete
#  [*****************81%***********       ]  324 of 400 complete
#  [*****************81%***********       ]  325 of 400 complete
#  [*****************82%***********       ]  326 of 400 complete
#  [*****************82%***********       ]  327 of 400 complete
#  [*****************82%***********       ]  328 of 400 complete
#  [*****************82%***********       ]  329 of 400 complete
#  [*****************82%***********       ]  330 of 400 complete
#  [*****************83%************      ]  331 of 400 complete
#  [*****************83%************      ]  332 of 400 complete
#  [*****************83%************      ]  333 of 400 complete
#  [*****************84%************      ]  334 of 400 complete
#  [*****************84%************      ]  335 of 400 complete
#  [*****************84%************      ]  336 of 400 complete
#  [*****************84%************      ]  337 of 400 complete
#  [*****************84%************      ]  338 of 400 complete
#  [*****************85%************      ]  339 of 400 complete
#  [*****************85%************      ]  340 of 400 complete
#  [*****************85%************      ]  341 of 400 complete
#  [*****************86%*************     ]  342 of 400 complete
#  [*****************86%*************     ]  343 of 400 complete
#  [*****************86%*************     ]  344 of 400 complete
#  [*****************86%*************     ]  345 of 400 complete
#  [*****************86%*************     ]  346 of 400 complete
#  [*****************87%*************     ]  347 of 400 complete
#  [*****************87%*************     ]  348 of 400 complete
#  [*****************87%*************     ]  349 of 400 complete
#  [*****************88%*************     ]  350 of 400 complete
#  [*****************88%*************     ]  351 of 400 complete
#  [*****************88%*************     ]  352 of 400 complete
#  [*****************88%*************     ]  353 of 400 complete
#  [*****************88%*************     ]  354 of 400 complete
#  [*****************89%**************    ]  355 of 400 complete
#  [*****************89%**************    ]  356 of 400 complete
#  [*****************89%**************    ]  357 of 400 complete
#  [*****************90%**************    ]  358 of 400 complete
#  [*****************90%**************    ]  359 of 400 complete
#  [*****************90%**************    ]  360 of 400 complete
#  [*****************90%**************    ]  361 of 400 complete
#  [*****************90%**************    ]  362 of 400 complete
#  [*****************91%***************   ]  363 of 400 complete
#  [*****************91%***************   ]  364 of 400 complete
#  [*****************91%***************   ]  365 of 400 complete
# ...
#  [*****************49%                  ]  195 of 400 complete
#  [*****************49%                  ]  196 of 400 complete
#  [*****************49%                  ]  197 of 400 complete
#  [*****************50%                  ]  198 of 400 complete
#  [*****************50%                  ]  199 of 400 complete
#  [*****************50%                  ]  200 of 400 complete
#  [*****************50%                  ]  201 of 400 complete
#  [*****************50%                  ]  202 of 400 complete
#  [*****************51%                  ]  203 of 400 complete
#  [*****************51%                  ]  204 of 400 complete
#  [*****************51%                  ]  205 of 400 complete
#  [*****************52%                  ]  206 of 400 complete
#  [*****************52%                  ]  207 of 400 complete
#  [*****************52%                  ]  208 of 400 complete
#  [*****************52%                  ]  209 of 400 complete
#  [*****************52%                  ]  210 of 400 complete
#  [*****************53%                  ]  211 of 400 complete
#  [*****************53%                  ]  212 of 400 complete
#  [*****************53%                  ]  213 of 400 complete
#  [*****************54%*                 ]  214 of 400 complete
#  [*****************54%*                 ]  215 of 400 complete
#  [*****************54%*                 ]  216 of 400 complete
#  [*****************54%*                 ]  217 of 400 complete
#  [*****************55%*                 ]  218 of 400 complete
#  [*****************55%*                 ]  219 of 400 complete
#  [*****************55%*                 ]  220 of 400 complete
#  [*****************55%*                 ]  221 of 400 complete
#  [*****************56%*                 ]  222 of 400 complete
#  [*****************56%*                 ]  223 of 400 complete
#  [*****************56%*                 ]  224 of 400 complete
#  [*****************56%*                 ]  225 of 400 complete
#  [*****************56%*                 ]  226 of 400 complete
#  [*****************57%**                ]  227 of 400 complete
#  [*****************57%**                ]  228 of 400 complete
#  [*****************57%**                ]  229 of 400 complete
#  [*****************57%**                ]  230 of 400 complete
#  [*****************58%**                ]  231 of 400 complete
#  [*****************58%**                ]  232 of 400 complete
#  [*****************58%**                ]  233 of 400 complete
#  [*****************58%**                ]  234 of 400 complete
#  [*****************59%**                ]  235 of 400 complete
#  [*****************59%**                ]  236 of 400 complete
#  [*****************59%**                ]  237 of 400 complete
#  [*****************60%***               ]  238 of 400 complete
#  [*****************60%***               ]  239 of 400 complete
#  [*****************60%***               ]  240 of 400 complete
#  [*****************60%***               ]  241 of 400 complete
#  [*****************60%***               ]  242 of 400 complete
#  [*****************61%***               ]  243 of 400 complete
#  [*****************61%***               ]  244 of 400 complete
#  [*****************61%***               ]  245 of 400 complete
#  [*****************62%****              ]  246 of 400 complete
#  [*****************62%****              ]  247 of 400 complete
#  [*****************62%****              ]  248 of 400 complete
#  [*****************62%****              ]  249 of 400 complete
#  [*****************62%****              ]  250 of 400 complete
#  [*****************63%****              ]  251 of 400 complete
#  [*****************63%****              ]  252 of 400 complete
#  [*****************63%****              ]  253 of 400 complete
#  [*****************64%****              ]  254 of 400 complete
#  [*****************64%****              ]  255 of 400 complete
#  [*****************64%****              ]  256 of 400 complete
#  [*****************64%****              ]  257 of 400 complete
#  [*****************64%****              ]  258 of 400 complete
#  [*****************65%*****             ]  259 of 400 complete
#  [*****************65%*****             ]  260 of 400 complete
#  [*****************65%*****             ]  261 of 400 complete
#  [*****************66%*****             ]  262 of 400 complete
#  [*****************66%*****             ]  263 of 400 complete
#  [*****************66%*****             ]  264 of 400 complete
#  [*****************66%*****             ]  265 of 400 complete
#  [*****************66%*****             ]  266 of 400 complete
#  [*****************67%*****             ]  267 of 400 complete
#  [*****************67%*****             ]  268 of 400 complete
#  [*****************67%*****             ]  269 of 400 complete
#  [*****************68%******            ]  270 of 400 complete
#  [*****************68%******            ]  271 of 400 complete
#  [*****************68%******            ]  272 of 400 complete
#  [*****************68%******            ]  273 of 400 complete
#  [*****************68%******            ]  274 of 400 complete
#  [*****************69%******            ]  275 of 400 complete
#  [*****************69%******            ]  276 of 400 complete
#  [*****************69%******            ]  277 of 400 complete
#  [*****************70%*******           ]  278 of 400 complete
#  [*****************70%*******           ]  279 of 400 complete
#  [*****************70%*******           ]  280 of 400 complete
#  [*****************70%*******           ]  281 of 400 complete
#  [*****************70%*******           ]  282 of 400 complete
#  [*****************71%*******           ]  283 of 400 complete
#  [*****************71%*******           ]  284 of 400 complete
#  [*****************71%*******           ]  285 of 400 complete
#  [*****************72%*******           ]  286 of 400 complete
#  [*****************72%*******           ]  287 of 400 complete
#  [*****************72%*******           ]  288 of 400 complete
#  [*****************72%*******           ]  289 of 400 complete
#  [*****************72%*******           ]  290 of 400 complete
#  [*****************73%********          ]  291 of 400 complete
#  [*****************73%********          ]  292 of 400 complete
#  [*****************73%********          ]  293 of 400 complete
#  [*****************74%********          ]  294 of 400 complete
#  [*****************74%********          ]  295 of 400 complete
#  [*****************74%********          ]  296 of 400 complete
#  [*****************74%********          ]  297 of 400 complete
#  [*****************74%********          ]  298 of 400 complete
#  [*****************75%********          ]  299 of 400 complete
#  [*****************75%********          ]  300 of 400 complete
#  [*****************75%********          ]  301 of 400 complete
#  [*****************76%*********         ]  302 of 400 complete
#  [*****************76%*********         ]  303 of 400 complete
#  [*****************76%*********         ]  304 of 400 complete
#  [*****************76%*********         ]  305 of 400 complete
#  [*****************76%*********         ]  306 of 400 complete
#  [*****************77%*********         ]  307 of 400 complete
#  [*****************77%*********         ]  308 of 400 complete
#  [*****************77%*********         ]  309 of 400 complete
#  [*****************78%**********        ]  310 of 400 complete
#  [*****************78%**********        ]  311 of 400 complete
#  [*****************78%**********        ]  312 of 400 complete
#  [*****************78%**********        ]  313 of 400 complete
#  [*****************78%**********        ]  314 of 400 complete
#  [*****************79%**********        ]  315 of 400 complete
#  [*****************79%**********        ]  316 of 400 complete
#  [*****************79%**********        ]  317 of 400 complete
#  [*****************80%**********        ]  318 of 400 complete
#  [*****************80%**********        ]  319 of 400 complete
#  [*****************80%**********        ]  320 of 400 complete
#  [*****************80%**********        ]  321 of 400 complete
#  [*****************80%**********        ]  322 of 400 complete
#  [*****************81%***********       ]  323 of 400 complete
#  [*****************81%***********       ]  324 of 400 complete
#  [*****************81%***********       ]  325 of 400 complete
#  [*****************82%***********       ]  326 of 400 complete
#  [*****************82%***********       ]  327 of 400 complete
#  [*****************82%***********       ]  328 of 400 complete
#  [*****************82%***********       ]  329 of 400 complete
#  [*****************82%***********       ]  330 of 400 complete
#  [*****************83%************      ]  331 of 400 complete
#  [*****************83%************      ]  332 of 400 complete
#  [*****************83%************      ]  333 of 400 complete
#  [*****************84%************      ]  334 of 400 complete
#  [*****************84%************      ]  335 of 400 complete
#  [*****************84%************      ]  336 of 400 complete
#  [*****************84%************      ]  337 of 400 complete
#  [*****************84%************      ]  338 of 400 complete
#  [*****************85%************      ]  339 of 400 complete
#  [*****************85%************      ]  340 of 400 complete
#  [*****************85%************      ]  341 of 400 complete
#  [*****************86%*************     ]  342 of 400 complete
#  [*****************86%*************     ]  343 of 400 complete
#  [*****************86%*************     ]  344 of 400 complete
#  [*****************86%*************     ]  345 of 400 complete
#  [*****************86%*************     ]  346 of 400 complete
#  [*****************87%*************     ]  347 of 400 complete
#  [*****************87%*************     ]  348 of 400 complete
#  [*****************87%*************     ]  349 of 400 complete
#  [*****************88%*************     ]  350 of 400 complete
#  [*****************88%*************     ]  351 of 400 complete
#  [*****************88%*************     ]  352 of 400 complete
#  [*****************88%*************     ]  353 of 400 complete
#  [*****************88%*************     ]  354 of 400 complete
#  [*****************89%**************    ]  355 of 400 complete
#  [*****************89%**************    ]  356 of 400 complete
#  [*****************89%**************    ]  357 of 400 complete
#  [*****************90%**************    ]  358 of 400 complete
#  [*****************90%**************    ]  359 of 400 complete
#  [*****************90%**************    ]  360 of 400 complete
#  [*****************90%**************    ]  361 of 400 complete
#  [*****************90%**************    ]  362 of 400 complete
#  [*****************91%***************   ]  363 of 400 complete
#  [*****************91%***************   ]  364 of 400 complete
#  [*****************91%***************   ]  365 of 400 complete
#  [*****************92%***************   ]  366 of 400 complete
#  [*****************92%***************   ]  367 of 400 complete
#  [*****************92%***************   ]  368 of 400 complete
#  [*****************92%***************   ]  369 of 400 complete
#  [*****************92%***************   ]  370 of 400 complete
#  [*****************93%***************   ]  371 of 400 complete
#  [*****************93%***************   ]  372 of 400 complete
#  [*****************93%***************   ]  373 of 400 complete
#  [*****************94%****************  ]  374 of 400 complete
#  [*****************94%****************  ]  375 of 400 complete
#  [*****************94%****************  ]  376 of 400 complete
#  [*****************94%****************  ]  377 of 400 complete
#  [*****************94%****************  ]  378 of 400 complete
#  [*****************95%****************  ]  379 of 400 complete
#  [*****************95%****************  ]  380 of 400 complete
#  [*****************95%****************  ]  381 of 400 complete
#  [*****************96%****************  ]  382 of 400 complete
#  [*****************96%****************  ]  383 of 400 complete
#  [*****************96%****************  ]  384 of 400 complete
#  [*****************96%****************  ]  385 of 400 complete
#  [*****************96%****************  ]  386 of 400 complete
#  [*****************97%***************** ]  387 of 400 complete
#  [*****************97%***************** ]  388 of 400 complete
#  [*****************97%***************** ]  389 of 400 complete
#  [*****************98%***************** ]  390 of 400 complete
#  [*****************98%***************** ]  391 of 400 complete
#  [*****************98%***************** ]  392 of 400 complete
#  [*****************98%***************** ]  393 of 400 complete
#  [*****************98%***************** ]  394 of 400 complete
#  [*****************99%******************]  395 of 400 complete
#  [*****************99%******************]  396 of 400 complete
#  [*****************99%******************]  397 of 400 complete
#  [****************100%******************]  398 of 400 complete
#  [****************100%******************]  399 of 400 complete
#  [****************100%******************]  400 of 400 complete
#  [                  0%                  ]
#  [                  0%                  ]  2 of 400 complete
#  [                  1%                  ]  3 of 400 complete
#  [                  1%                  ]  4 of 400 complete
#  [                  1%                  ]  5 of 400 complete
#  [*                 2%                  ]  6 of 400 complete
#  [*                 2%                  ]  7 of 400 complete
#  [*                 2%                  ]  8 of 400 complete
#  [*                 2%                  ]  9 of 400 complete
#  [*                 2%                  ]  10 of 400 complete
#  [*                 3%                  ]  11 of 400 complete
#  [*                 3%                  ]  12 of 400 complete
#  [*                 3%                  ]  13 of 400 complete
#  [**                4%                  ]  14 of 400 complete
#  [**                4%                  ]  15 of 400 complete
#  [**                4%                  ]  16 of 400 complete
#  [**                4%                  ]  17 of 400 complete
#  [**                4%                  ]  18 of 400 complete
#  [**                5%                  ]  19 of 400 complete
#  [**                5%                  ]  20 of 400 complete
#  [**                5%                  ]  21 of 400 complete
#  [**                6%                  ]  22 of 400 complete
#  [**                6%                  ]  23 of 400 complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8517f85dfaf3> in <module>()
#       9     t = KnnDtw(n_neighbors=1, max_warping_window=w)
#      10     t.fit(x_train[:20], y_train[:20])
# ---> 11     label, proba = t.predict(x_test[:20])
#      12
#      13     end = time.time()
#
# <ipython-input-11-290578c2e882> in predict(self, x)
#     172         """
#     173
# --> 174         dm = self._dist_matrix(x, self.x)
#     175
#     176         # Identify the k nearest neighbors
#
# <ipython-input-11-290578c2e882> in _dist_matrix(self, x, y)
#     149                 for j in np.arange(0, y_s[0]):
#     150                     dm[i, j] = self._dtw_distance(x[i, ::self.subsample_step],
# --> 151                                                   y[j, ::self.subsample_step])
#     152                     # Update progress bar
#     153                     dm_count += 1
#
# <ipython-input-11-290578c2e882> in _dtw_distance(self, ts_a, ts_b, d)
#      93                             min(N, i + self.max_warping_window)):
#      94                 choices = cost[i - 1, j - 1], cost[i, j-1], cost[i-1, j]
# ---> 95                 cost[i, j] = min(choices) + d(ts_a[i], ts_b[j])
#      96
#      97         # Return DTW distance given window
#
# <ipython-input-11-290578c2e882> in <lambda>(x, y)
#      55         self.l = l
#      56
# ---> 57     def _dtw_distance(self, ts_a, ts_b, d = lambda x,y: abs(x-y)):
#      58         """Returns the DTW similarity distance between two 2-D
#      59         timeseries numpy arrays.
#
# KeyboardInterrupt:

# %% [markdown]
# ---
#
# #### Final thoughts
# There are many improvements that could be made to this python implementation of KNN & DTW (eg. rewrite in C++ or explore parallel processing). However, the objective of this project was learning related. I've gained a deeper insight into the underlying mechanics of DTW by implementing it in python using dynamic programming techniques.
#
# #### References
# 1.  Mitsa (2010). Temporal Data Mining (Chapter on Temporal Classification).
# 2.  Xi (2006). Fast Time Series Classification Using Numerosity Reduction.
# 3.  Davide Anguita, Alessandro Ghio, Luca Oneto, Xavier Parra and Jorge L. Reyes-Ortiz. Human Activity Recognition on Smartphones using a Multiclass Hardware-Friendly Support Vector Machine. International Workshop of Ambient Assisted Living (IWAAL 2012). Vitoria-Gasteiz, Spain. Dec 2012. [Read Paper](http://arxiv.org/pdf/1401.8212.pdf)
#
# #### Credit
# -  The progressbar used in the `DtwKnn()` class was taken from PYMC
# -  The matplotlib style and IPython notebook was taken from Cameron Davidson-Pilon's excelent ["Bayesian Methods for Hackers"](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers)

# %%
from IPython.core.display import HTML

def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
